# %%
# Import the dependencies.
import pandas as pd
import gmaps
import gmaps.datasets
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved/created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID        City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0        0      Bethel  41.3712 -73.4140     77.36        80           0
# 1        1  Nanortalik  60.1432 -45.2371     39.74        89         100
# 2        2   Kavaratti  10.5669  72.6420     80.46        80         100
# 3        3    Qaqortoq  60.7167 -46.0333     39.65        88          97
# 4        4      Oppdal  62.5943   9.6912     40.01        92          81
#
#    Wind Speed Country                 Date
# 0        7.02      US  2022-08-30 01:33:06
# 1        6.71      GL  2022-08-30 01:33:07
# 2       18.54      IN  2022-08-30 01:33:07
# 3        4.74      GL  2022-08-30 01:33:08
# 4        1.86      NO  2022-08-30 01:33:08

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
#HEATMAP FOR MAX TEMP

# 1. Assign the locations to an array of latitude and longitude pairs.
locations = city_data_df[["Lat", "Lng"]]

# 2. Assign the weights variable to some values.

# an array of length equal to the locations array length
max_temp = city_data_df["Max Temp"]

# 3. Assign the figure variable to the gmaps.figure() attribute.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# 4. Assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)

# 5. Add the heatmap layer.
fig.add_layer(heat_layer)
# 6. Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudiness
locations = city_data_df[["Lat", "Lng"]]
cloudiness = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=cloudiness, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of wind speed
locations = city_data_df[["Lat", "Lng"]]
wind_speed = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind_speed, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.

preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)

# Recall : Recall that you use the loc[] method on the current DataFrame to create a new DataFrame from a current DataFrame. 
# Inside the brackets, add the conditional filter.
# Out:
#     City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         0       Bethel  41.3712  -73.4140     77.36        80           0
# 2         2    Kavaratti  10.5669   72.6420     80.46        80         100
# 5         5        Ambon  -3.6954  128.1814     82.54        83          75
# 15       15       Atuona  -9.8000 -139.0333     76.91        74           3
# 19       19       Kawalu  -7.3817  108.2082     77.04        75         100
# 24       24       Avarua -21.2078 -159.7750     78.85        78          71
# 28       28  Bandarbeyla   9.4942   50.8122     75.47        82          15
# 29       29       Riyadh  24.6877   46.7219     80.74        16           0
# 30       30      Isangel -19.5500  169.2667     75.74        65          62
# 32       32       Touros  -5.1989  -35.4608     75.67        80          43
#
#     Wind Speed Country                 Date
# 0         7.02      US  2022-08-30 01:33:06
# 2        18.54      IN  2022-08-30 01:33:07
# 5         3.44      ID  2022-08-30 01:33:09
# 15       21.05      PF  2022-08-30 01:33:13
# 19        3.60      ID  2022-08-30 01:33:14
# 24        9.22      CK  2022-08-30 01:33:16
# 28       21.50      SO  2022-08-30 01:33:18
# 29        6.69      SA  2022-08-30 01:29:08
# 30       15.79      VU  2022-08-30 01:33:18
# 32       16.17      BR  2022-08-30 01:33:19

# %%
#Are there any null values?
preferred_cities_df.count()
# Out:
# City_ID       210
# City          210
# Lat           210
# Lng           210
# Max Temp      210
# Humidity      210
# Cloudiness    210
# Wind Speed    210
# Country       210
# Date          210
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#            City Country  Max Temp      Lat       Lng Hotel Name
# 0        Bethel      US     77.36  41.3712  -73.4140
# 2     Kavaratti      IN     80.46  10.5669   72.6420
# 5         Ambon      ID     82.54  -3.6954  128.1814
# 15       Atuona      PF     76.91  -9.8000 -139.0333
# 19       Kawalu      ID     77.04  -7.3817  108.2082
# 24       Avarua      CK     78.85 -21.2078 -159.7750
# 28  Bandarbeyla      SO     75.47   9.4942   50.8122
# 29       Riyadh      SA     80.74  24.6877   46.7219
# 30      Isangel      VU     75.74 -19.5500  169.2667
# 32       Touros      BR     75.67  -5.1989  -35.4608

# %% [markdown]
# ## Nearby Search using Google API

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotels
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.9733666, 'lng': -87.97881},
#     'viewport': {'northeast': {'lat': 42.9749521802915,
#       'lng': -87.9774164697085},
#      'southwest': {'lat': 42.9722542197085, 'lng': -87.98011443029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet',
#    'name': 'Brewtown Eatery Bar & Grill',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113235049403841608129">Dave Michalski</a>'],
#      'photo_reference': 'AeJbb3dFgHmZRBxGhm_NhhQbojU5FxRQomdNMx8kSaQTRkFtC28cDEkkcd738szkZNl5sAEXT8WHVcS34VKKI9frh1PwNhJ8wITBDN1SMiS7wObhZI91Xg96a95-feA1t0F62M8MPtFd-8Oqt_SXHdwMMul1e4jdkORZdj94ZK2kHZaoyThW',
#      'width': 4032}],
#    'place_id': 'ChIJPcVJE1oQBYgRAKU0mj6JnJ8',
#    'plus_code': {'compound_code': 'X2FC+8F Milwaukee, WI, USA',
#     'global_code': '86JJX2FC+8F'},
#    'price_level': 2,
#    'rating': 4.2,
#    'reference': 'ChIJPcVJE1oQBYgRAKU0mj6JnJ8',
#    'scope': 'GOOGLE',
#    'types': ['bar',
#     'lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 386,
#    'vicinity': '5121 West Howard Avenue, Milwaukee'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.9232437, 'lng': -88.02865159999999},
#     'viewport': {'northeast': {'lat': 42.9245931802915,
#       'lng': -88.0273358197085},
#      'southwest': {'lat': 42.9218952197085, 'lng': -88.0300337802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Will & Cava Ross Lodge',
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113279871473932683271">Nat Benavides</a>'],
#      'photo_reference': 'AeJbb3ejzdakvzG4gPzm3CJHEyWxMtVaygcoNbDtvGwL7I9KNIZ5Qbd_lImEhtTZPNppttAjJNL_75xnINO1BJtZjXuN8jSIbCuBy_wT9Bot66rK-pC9xe--1FmoHu2Rm8g12di0zoEgVU4zzJvNyHbqf9tA_e1-srL9FQwgHSE50I2WIavk',
#      'width': 3024}],
#    'place_id': 'ChIJdcvgkuENBYgRRFcYB5g5PYk',
#    'plus_code': {'compound_code': 'WXFC+7G Franklin, WI, USA',
#     'global_code': '86JHWXFC+7G'},
#    'rating': 4.4,
#    'reference': 'ChIJdcvgkuENBYgRRFcYB5g5PYk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 8,
#    'vicinity': '6750 South 92nd Street, Franklin'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.9171375, 'lng': -88.0100101},
#     'viewport': {'northeast': {'lat': 42.9187632802915,
#       'lng': -88.0082700697085},
#      'southwest': {'lat': 42.9160653197085, 'lng': -88.01096803029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hampton Inn & Suites Milwaukee/Franklin',
#    'photos': [{'height': 1365,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110349605065224865923">Hampton Inn &amp; Suites Milwaukee/Franklin</a>'],
#      'photo_reference': 'AeJbb3ekR14MNIZACZRpnHyDTZHNpP_BlPQmfkN993n8iO5G9SDUT55H8eLk1mSGByQWSRNSi-v9tztUbh17n61Jnqvqh_In9-jipaK2TK1O0MT0VQBYSRp82Tsx2Iy_Qql9Gc494th-_XPF-W5q0d8WcAqwU72i1cAzCOroTAjROv-FgcHy',
#      'width': 2048}],
#    'place_id': 'ChIJMYI8qAcSBYgR2aKMBv8j2Zk',
#    'plus_code': {'compound_code': 'WX8Q+VX Franklin, WI, USA',
#     'global_code': '86JHWX8Q+VX'},
#    'rating': 4.6,
#    'reference': 'ChIJMYI8qAcSBYgR2aKMBv8j2Zk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 602,
#    'vicinity': '6901 South 76th Street, Franklin'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.9782939, 'lng': -88.0466852},
#     'viewport': {'northeast': {'lat': 42.9796431802915,
#       'lng': -88.0453837697085},
#      'southwest': {'lat': 42.9769452197085, 'lng': -88.0480817302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Golden Key Motel',
#    'photos': [{'height': 2663,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113436300089810212847">Kelly Kelnhofer</a>'],
#      'photo_reference': 'AeJbb3cPM8es_JlvEf7oMbvI-zIRaiA7r9rLVqZq-GyRx1dvih1sJYrGLDP8-mcdklKDqSu-rewrW-NvoJDEBtf5_6Tnub7kFjWAyzxP2utHkQ50Zo6APpU1gIDx51KM9IAybDkPGY6t7t8KQTUMtdsZI3a9UCz_mzAr7q_x1GYCF8s9u_V3',
#      'width': 4816}],
#    'place_id': 'ChIJNeGIQKEPBYgREbncQsANjdE',
#    'plus_code': {'compound_code': 'XXH3+88 Greenfield, WI, USA',
#     'global_code': '86JHXXH3+88'},
#    'rating': 2.5,
#    'reference': 'ChIJNeGIQKEPBYgREbncQsANjdE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 157,
#    'vicinity': '3600 South 108th Street, Greenfield'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.92493, 'lng': -88.04286119999999},
#     'viewport': {'northeast': {'lat': 42.9260225802915,
#       'lng': -88.0415167197085},
#      'southwest': {'lat': 42.9233246197085, 'lng': -88.0442146802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Corp Housing Equity',
#    'place_id': 'ChIJP5b559cNBYgRmK3TQlL_D6U',
#    'plus_code': {'compound_code': 'WXF4+XV Franklin, WI, USA',
#     'global_code': '86JHWXF4+XV'},
#    'reference': 'ChIJP5b559cNBYgRmK3TQlL_D6U',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '6641 West Parkwood Drive, Franklin'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.9401918, 'lng': -88.0418165},
#     'viewport': {'northeast': {'lat': 42.9416288802915,
#       'lng': -88.04060321970849},
#      'southwest': {'lat': 42.9389309197085, 'lng': -88.04330118029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'The Lawson House Bed & Breakfast',
#    'place_id': 'ChIJRXTGIWYOBYgRUpG1b8vdZCY',
#    'plus_code': {'compound_code': 'WXR5+37 Hales Corners, WI, USA',
#     'global_code': '86JHWXR5+37'},
#    'rating': 5,
#    'reference': 'ChIJRXTGIWYOBYgRUpG1b8vdZCY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 5,
#    'vicinity': '10265 West Forest Home Avenue, Hales Corners'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 42.98373489999999,
#      'lng': -88.03050139999999},
#     'viewport': {'northeast': {'lat': 42.9850856302915,
#       'lng': -88.02928196970849},
#      'southwest': {'lat': 42.9823876697085, 'lng': -88.0319799302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Emerald Builders Inc',
#    'permanently_closed': True,
#    'place_id': 'ChIJWcbZouoPBYgR9oJLaDO9Qoc',
#    'plus_code': {'compound_code': 'XXM9+FQ Milwaukee, WI, USA',
#     'global_code': '86JHXXM9+FQ'},
#    'rating': 2,
#    'reference': 'ChIJWcbZouoPBYgR9oJLaDO9Qoc',
#    'scope': 'GOOGLE',
#    'types': ['real_estate_agency',
#     'lodging',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '3334 South 95th Street, Milwaukee'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.9386397, 'lng': -87.9921633},
#     'viewport': {'northeast': {'lat': 42.9400137302915,
#       'lng': -87.99087886970848},
#      'southwest': {'lat': 42.9373157697085, 'lng': -87.9935768302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Cottage on Clover',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJO0nLWdkRBYgR480763fyXZU',
#    'plus_code': {'compound_code': 'W2Q5+F4 Greendale, WI, USA',
#     'global_code': '86JJW2Q5+F4'},
#    'reference': 'ChIJO0nLWdkRBYgR480763fyXZU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '5720 Clover Lane, Greendale'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.9384254, 'lng': -87.9924023},
#     'viewport': {'northeast': {'lat': 42.9398163802915,
#       'lng': -87.9911134697085},
#      'southwest': {'lat': 42.9371184197085, 'lng': -87.9938114302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Guesthouse on Clover',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107026359180596431619">Guesthouse on Clover</a>'],
#      'photo_reference': 'AeJbb3dYaEGsPAgxFPcOnuRcySc6l18hXteK-W0cz_SqehOrLG2mSNUpsYt8VYXge1863dkTaJ3Cx_yruvxiT6tKIMkK9vfOLDVH_E4kufOXzhy4pdHOzKEwEYS_jPpeZI8zuxiM3wo8IvxwQ0yahLLRT6vYYmhNUO8HYoQN5vza8sNouJdW',
#      'width': 4032}],
#    'place_id': 'ChIJZZ_EnkQRBYgR_8MzAHaDums',
#    'plus_code': {'compound_code': 'W2Q5+92 Greendale, WI, USA',
#     'global_code': '86JJW2Q5+92'},
#    'rating': 5,
#    'reference': 'ChIJZZ_EnkQRBYgR_8MzAHaDums',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 5,
#    'vicinity': '5724 Clover Lane, Greendale'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.980284, 'lng': -87.9846388},
#     'viewport': {'northeast': {'lat': 42.9816305302915,
#       'lng': -87.9831314697085},
#      'southwest': {'lat': 42.9789325697085, 'lng': -87.98582943029152}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Morgan Deluxe Apartments',
#    'place_id': 'ChIJ82XDWosRBYgRg7bCw2b_Gx8',
#    'plus_code': {'compound_code': 'X2J8+44 Milwaukee, WI, USA',
#     'global_code': '86JJX2J8+44'},
#    'reference': 'ChIJ82XDWosRBYgRg7bCw2b_Gx8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Morgan Court, 5609 West Morgan Avenue, Milwaukee'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.9826708, 'lng': -88.0399511},
#     'viewport': {'northeast': {'lat': 42.9840152802915,
#       'lng': -88.0391258197085},
#      'southwest': {'lat': 42.9813173197085, 'lng': -88.04182378029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#    'name': 'Smith & Nephew',
#    'photos': [{'height': 2514,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104110205251173492031">Dave Shapiro</a>'],
#      'photo_reference': 'AeJbb3fuPO31u1M6r0_sG9rYjH7NcEQksoFxBew2BAyar9eSHbgmumWhdVoJmh1pdxK__r9QEfAMOqGeXB0hmGY8zoAvF0SGblCxz4ck864kNiETeBXsMWqatIsOsERsoGVldvku2skQMAZKWqqlicStGBinpYgbYfb-NjUZrHvQ57swndfY',
#      'width': 2713}],
#    'place_id': 'ChIJ-1zRdpcPBYgRi2bH_H0T8NU',
#    'plus_code': {'compound_code': 'XXM6+32 Milwaukee, WI, USA',
#     'global_code': '86JHXXM6+32'},
#    'rating': 4,
#    'reference': 'ChIJ-1zRdpcPBYgRi2bH_H0T8NU',
#    'scope': 'GOOGLE',
#    'types': ['campground',
#     'park',
#     'lodging',
#     'health',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': '3400 South 103rd Street, Milwaukee'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 42.9258175, 'lng': -88.0423046},
#     'viewport': {'northeast': {'lat': 42.92728443029151,
#       'lng': -88.04087056970849},
#      'southwest': {'lat': 42.92458646970851, 'lng': -88.0435685302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Wisconsin Condo',
#    'permanently_closed': True,
#    'place_id': 'ChIJPQ8_kbwPBYgRVgJ7EfD9tNs',
#    'plus_code': {'compound_code': 'WXG5+83 Franklin, WI, USA',
#     'global_code': '86JHWXG5+83'},
#    'reference': 'ChIJPQ8_kbwPBYgRVgJ7EfD9tNs',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '10335 West Parkwood Drive, Franklin'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 42.99951639999999,
#      'lng': -88.04121219999999},
#     'viewport': {'northeast': {'lat': 43.00030509999998,
#       'lng': -88.04022791970849},
#      'southwest': {'lat': 42.99715030000001, 'lng': -88.04292588029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'My Resort Connections',
#    'place_id': 'ChIJBxcQJIYPBYgRb3WiKCo4zSE',
#    'plus_code': {'compound_code': 'XXX5+RG Milwaukee, WI, USA',
#     'global_code': '86JHXXX5+RG'},
#    'reference': 'ChIJBxcQJIYPBYgRb3WiKCo4zSE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '2448 South 102nd Street, Milwaukee'}],
#  'status': 'OK'}

# %%
hotel_df.head()
# Out:
#          City Country  Max Temp      Lat       Lng  \
# 0      Bethel      US     77.36  41.3712  -73.4140
# 2   Kavaratti      IN     80.46  10.5669   72.6420
# 5       Ambon      ID     82.54  -3.6954  128.1814
# 15     Atuona      PF     76.91  -9.8000 -139.0333
# 19     Kawalu      ID     77.04  -7.3817  108.2082
#
#                        Hotel Name
# 0   Courtyard by Marriott Danbury
# 2                      Green leaf
# 5            Swiss-Belhotel Ambon
# 15    Hôtel Hiva Oa Hanakee Lodge
# 19                    West Jontor

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# Store to the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]


# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ## Practice using fixed latitude and longitude

# %%
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}

# %%
url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'

nearby_response = requests.get(url,params=params).json()

# %%
nearby_response

# %%
#To get all the hotels in the results dictionary we can get the length of this dictionary by using, 
#len(hotels["results"])

len(nearby_response["results"])

# %%
nearby_response['results'][0]['name']
