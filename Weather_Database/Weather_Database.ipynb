# %%
#Import Dependencies 
import numpy as np
import pandas as pd
import requests
from citipy import citipy
from config import weather_api_key
import time

# %%
lats = np.random.uniform(-90,90, size=2000)
lngs = np.random.uniform(-180,190, size= 20000)
lats_lngs= zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
cities = []

# %%
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)

# %%
len(cities)
# Out:
# 770

# %%
# Create empty list to store data 

city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list 

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Base url 
    url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        response = requests.get(city_url).json()
        # Parse out the needed data.
        Country = response['sys']['country']
        Lat = response['coord']['lat']
        Lng = response['coord']['lon']
        Max_temp = response['main']['temp_max']
        Humidity = response['main']['humidity']
        Clouds = response['clouds']['all']
        Wind_speed = response['wind']['speed']
        Weather_description = response['weather'][0]['description']
        
        city_data.append({"City": city.title(),
                          "Country": Country,
                          "Lat": Lat,
                          "Lng": Lng,
                          "Max Temp": Max_temp,
                          "Humidity": Humidity,
                          "Cloudiness": Clouds,
                          "Wind Speed": Wind_speed,
                          "Current Description": Weather_description
                         })
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | khatanga
# Processing Record 2 of Set 1 | kutum
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | arraial do cabo
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | washougal
# Processing Record 9 of Set 1 | ixtapa
# Processing Record 10 of Set 1 | padang
# Processing Record 11 of Set 1 | yar-sale
# Processing Record 12 of Set 1 | axim
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | san patricio
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 1 | puerto ayora
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | uthal
# Processing Record 22 of Set 1 | butaritari
# Processing Record 23 of Set 1 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | hualmay
# Processing Record 27 of Set 1 | pilao arcado
# City not found. Skipping...
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | lithgow
# Processing Record 30 of Set 1 | kavaratti
# Processing Record 31 of Set 1 | charleston
# Processing Record 32 of Set 1 | vila
# Processing Record 33 of Set 1 | kaitangata
# Processing Record 34 of Set 1 | hami
# Processing Record 35 of Set 1 | erzin
# Processing Record 36 of Set 1 | hilo
# Processing Record 37 of Set 1 | cabo san lucas
# Processing Record 38 of Set 1 | leshukonskoye
# Processing Record 39 of Set 1 | maghama
# City not found. Skipping...
# Processing Record 40 of Set 1 | thompson
# Processing Record 41 of Set 1 | dunedin
# Processing Record 42 of Set 1 | okha
# Processing Record 43 of Set 1 | lebu
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | bursol
# City not found. Skipping...
# Processing Record 46 of Set 1 | port hedland
# Processing Record 47 of Set 1 | mehamn
# Processing Record 48 of Set 1 | chifeng
# Processing Record 49 of Set 1 | mizan teferi
# Processing Record 50 of Set 1 | vaini
# Processing Record 1 of Set 2 | barnala
# Processing Record 2 of Set 2 | east london
# Processing Record 3 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 2 | asau
# Processing Record 5 of Set 2 | coolum beach
# Processing Record 6 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 2 | nikolskoye
# Processing Record 8 of Set 2 | san juan
# Processing Record 9 of Set 2 | ushuaia
# Processing Record 10 of Set 2 | medicine hat
# Processing Record 11 of Set 2 | fortuna
# Processing Record 12 of Set 2 | bourail
# Processing Record 13 of Set 2 | sept-iles
# Processing Record 14 of Set 2 | luderitz
# Processing Record 15 of Set 2 | pappadatai
# Processing Record 16 of Set 2 | shamary
# Processing Record 17 of Set 2 | kaeo
# Processing Record 18 of Set 2 | busselton
# Processing Record 19 of Set 2 | tuatapere
# Processing Record 20 of Set 2 | port alfred
# Processing Record 21 of Set 2 | hasaki
# Processing Record 22 of Set 2 | juruti
# Processing Record 23 of Set 2 | kruisfontein
# Processing Record 24 of Set 2 | cape town
# Processing Record 25 of Set 2 | clyde river
# Processing Record 26 of Set 2 | mount isa
# Processing Record 27 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 2 | am timan
# Processing Record 29 of Set 2 | faanui
# Processing Record 30 of Set 2 | black river
# Processing Record 31 of Set 2 | angoram
# Processing Record 32 of Set 2 | makakilo city
# Processing Record 33 of Set 2 | tasiilaq
# Processing Record 34 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 2 | camargo
# Processing Record 36 of Set 2 | tarko-sale
# Processing Record 37 of Set 2 | koroni
# Processing Record 38 of Set 2 | souillac
# Processing Record 39 of Set 2 | sao filipe
# Processing Record 40 of Set 2 | carnarvon
# Processing Record 41 of Set 2 | masvingo
# Processing Record 42 of Set 2 | lavrentiya
# Processing Record 43 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 2 | severo-kurilsk
# Processing Record 45 of Set 2 | cherskiy
# Processing Record 46 of Set 2 | ternate
# Processing Record 47 of Set 2 | kaniama
# Processing Record 48 of Set 2 | aksha
# Processing Record 49 of Set 2 | sabang
# Processing Record 50 of Set 2 | bonthe
# Processing Record 1 of Set 3 | pevek
# Processing Record 2 of Set 3 | bilma
# Processing Record 3 of Set 3 | bentiu
# Processing Record 4 of Set 3 | thomastown
# Processing Record 5 of Set 3 | torbay
# Processing Record 6 of Set 3 | alyangula
# Processing Record 7 of Set 3 | keti bandar
# Processing Record 8 of Set 3 | ponta delgada
# Processing Record 9 of Set 3 | antofagasta
# Processing Record 10 of Set 3 | iqaluit
# Processing Record 11 of Set 3 | hermanus
# Processing Record 12 of Set 3 | ponta do sol
# Processing Record 13 of Set 3 | ugoofaaru
# Processing Record 14 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 3 | maniitsoq
# Processing Record 16 of Set 3 | obera
# Processing Record 17 of Set 3 | pisco
# Processing Record 18 of Set 3 | margate
# Processing Record 19 of Set 3 | zyryanka
# Processing Record 20 of Set 3 | saldanha
# Processing Record 21 of Set 3 | trairi
# Processing Record 22 of Set 3 | dickinson
# Processing Record 23 of Set 3 | albany
# Processing Record 24 of Set 3 | igarka
# Processing Record 25 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 3 | skibbereen
# Processing Record 27 of Set 3 | te anau
# Processing Record 28 of Set 3 | huilong
# Processing Record 29 of Set 3 | svencioneliai
# Processing Record 30 of Set 3 | sedelnikovo
# City not found. Skipping...
# Processing Record 31 of Set 3 | tuktoyaktuk
# Processing Record 32 of Set 3 | rudnya
# Processing Record 33 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 3 | rawson
# Processing Record 35 of Set 3 | boende
# Processing Record 36 of Set 3 | namibe
# Processing Record 37 of Set 3 | saint-pierre
# Processing Record 38 of Set 3 | ocampo
# Processing Record 39 of Set 3 | barrow
# Processing Record 40 of Set 3 | cidreira
# Processing Record 41 of Set 3 | amapa
# Processing Record 42 of Set 3 | blenheim
# Processing Record 43 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 3 | maicao
# Processing Record 45 of Set 3 | songjianghe
# Processing Record 46 of Set 3 | eyl
# Processing Record 47 of Set 3 | hope
# Processing Record 48 of Set 3 | georgetown
# Processing Record 49 of Set 3 | isangel
# Processing Record 50 of Set 3 | saint george
# Processing Record 1 of Set 4 | adrar
# Processing Record 2 of Set 4 | oranjestad
# Processing Record 3 of Set 4 | noumea
# Processing Record 4 of Set 4 | leningradskiy
# Processing Record 5 of Set 4 | boulder city
# Processing Record 6 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 7 of Set 4 | ghanzi
# Processing Record 8 of Set 4 | baruun-urt
# Processing Record 9 of Set 4 | bredasdorp
# Processing Record 10 of Set 4 | adre
# Processing Record 11 of Set 4 | camocim
# Processing Record 12 of Set 4 | rio tuba
# Processing Record 13 of Set 4 | oistins
# Processing Record 14 of Set 4 | machiques
# Processing Record 15 of Set 4 | kushalgarh
# Processing Record 16 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 4 | aklavik
# Processing Record 18 of Set 4 | manta
# Processing Record 19 of Set 4 | kurumkan
# Processing Record 20 of Set 4 | touros
# Processing Record 21 of Set 4 | iki-burul
# Processing Record 22 of Set 4 | peleduy
# Processing Record 23 of Set 4 | chokurdakh
# Processing Record 24 of Set 4 | sao jose da coroa grande
# Processing Record 25 of Set 4 | moiyabana
# City not found. Skipping...
# Processing Record 26 of Set 4 | bambous virieux
# Processing Record 27 of Set 4 | srednekolymsk
# Processing Record 28 of Set 4 | khambhaliya
# Processing Record 29 of Set 4 | rockhampton
# Processing Record 30 of Set 4 | atar
# Processing Record 31 of Set 4 | ullapool
# Processing Record 32 of Set 4 | guerrero negro
# Processing Record 33 of Set 4 | santa isabel do rio negro
# Processing Record 34 of Set 4 | caravelas
# Processing Record 35 of Set 4 | iralaya
# Processing Record 36 of Set 4 | hamilton
# Processing Record 37 of Set 4 | avarua
# Processing Record 38 of Set 4 | mayo
# Processing Record 39 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 4 | tura
# Processing Record 41 of Set 4 | talnakh
# Processing Record 42 of Set 4 | ormara
# Processing Record 43 of Set 4 | fare
# Processing Record 44 of Set 4 | longyearbyen
# Processing Record 45 of Set 4 | urumqi
# Processing Record 46 of Set 4 | gornopravdinsk
# Processing Record 47 of Set 4 | norman wells
# Processing Record 48 of Set 4 | altamont
# Processing Record 49 of Set 4 | shinuhayr
# Processing Record 50 of Set 4 | parker
# Processing Record 1 of Set 5 | casper
# Processing Record 2 of Set 5 | kulu
# Processing Record 3 of Set 5 | mahebourg
# Processing Record 4 of Set 5 | avera
# Processing Record 5 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 5 | carbonia
# Processing Record 7 of Set 5 | port moresby
# Processing Record 8 of Set 5 | zhezkazgan
# Processing Record 9 of Set 5 | krasnoarmeysk
# Processing Record 10 of Set 5 | nouakchott
# Processing Record 11 of Set 5 | alice springs
# Processing Record 12 of Set 5 | safford
# Processing Record 13 of Set 5 | nouadhibou
# Processing Record 14 of Set 5 | dikson
# Processing Record 15 of Set 5 | lorengau
# Processing Record 16 of Set 5 | ilulissat
# Processing Record 17 of Set 5 | aginskoye
# Processing Record 18 of Set 5 | presidencia roque saenz pena
# Processing Record 19 of Set 5 | altoona
# Processing Record 20 of Set 5 | nago
# Processing Record 21 of Set 5 | chilliwack
# Processing Record 22 of Set 5 | bata
# Processing Record 23 of Set 5 | yeppoon
# Processing Record 24 of Set 5 | hirara
# Processing Record 25 of Set 5 | bud
# Processing Record 26 of Set 5 | vila franca do campo
# Processing Record 27 of Set 5 | beringovskiy
# Processing Record 28 of Set 5 | kodiak
# Processing Record 29 of Set 5 | payakumbuh
# Processing Record 30 of Set 5 | bafq
# Processing Record 31 of Set 5 | seddon
# Processing Record 32 of Set 5 | port macquarie
# Processing Record 33 of Set 5 | hofn
# Processing Record 34 of Set 5 | knysna
# Processing Record 35 of Set 5 | portland
# Processing Record 36 of Set 5 | chuy
# Processing Record 37 of Set 5 | guilin
# Processing Record 38 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 5 | acapulco
# Processing Record 40 of Set 5 | codrington
# Processing Record 41 of Set 5 | koumac
# Processing Record 42 of Set 5 | salinas
# Processing Record 43 of Set 5 | esil
# Processing Record 44 of Set 5 | wenzhou
# Processing Record 45 of Set 5 | neepawa
# Processing Record 46 of Set 5 | nome
# Processing Record 47 of Set 5 | dingle
# Processing Record 48 of Set 5 | marienburg
# Processing Record 49 of Set 5 | tiksi
# Processing Record 50 of Set 5 | mazatlan
# Processing Record 1 of Set 6 | zalantun
# Processing Record 2 of Set 6 | rapid city
# Processing Record 3 of Set 6 | san cristobal
# Processing Record 4 of Set 6 | mar del plata
# Processing Record 5 of Set 6 | rio gallegos
# Processing Record 6 of Set 6 | tomaszow lubelski
# Processing Record 7 of Set 6 | haines junction
# Processing Record 8 of Set 6 | gisborne
# Processing Record 9 of Set 6 | saskylakh
# Processing Record 10 of Set 6 | puerto escondido
# Processing Record 11 of Set 6 | kokstad
# Processing Record 12 of Set 6 | durham
# Processing Record 13 of Set 6 | warwick
# Processing Record 14 of Set 6 | ondorhaan
# City not found. Skipping...
# Processing Record 15 of Set 6 | fairbanks
# Processing Record 16 of Set 6 | saint anthony
# Processing Record 17 of Set 6 | vabalninkas
# Processing Record 18 of Set 6 | flinders
# Processing Record 19 of Set 6 | juifang
# City not found. Skipping...
# Processing Record 20 of Set 6 | hambantota
# Processing Record 21 of Set 6 | tukrah
# Processing Record 22 of Set 6 | elati
# Processing Record 23 of Set 6 | fort oglethorpe
# Processing Record 24 of Set 6 | santa maria
# Processing Record 25 of Set 6 | zonalnoye
# City not found. Skipping...
# Processing Record 26 of Set 6 | kedrovyy
# Processing Record 27 of Set 6 | novocheremshansk
# Processing Record 28 of Set 6 | balrampur
# Processing Record 29 of Set 6 | ambilobe
# Processing Record 30 of Set 6 | paita
# Processing Record 31 of Set 6 | port elizabeth
# Processing Record 32 of Set 6 | praya
# Processing Record 33 of Set 6 | geresk
# City not found. Skipping...
# Processing Record 34 of Set 6 | kautokeino
# Processing Record 35 of Set 6 | tucupita
# Processing Record 36 of Set 6 | gat
# Processing Record 37 of Set 6 | port lincoln
# Processing Record 38 of Set 6 | castro
# Processing Record 39 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 6 | avola
# Processing Record 41 of Set 6 | gamba
# Processing Record 42 of Set 6 | victoria
# Processing Record 43 of Set 6 | panipat
# Processing Record 44 of Set 6 | port blair
# Processing Record 45 of Set 6 | jalu
# Processing Record 46 of Set 6 | buenaventura
# Processing Record 47 of Set 6 | oranjemund
# Processing Record 48 of Set 6 | ayr
# Processing Record 49 of Set 6 | cayenne
# Processing Record 50 of Set 6 | aleksandrovskiy zavod
# Processing Record 1 of Set 7 | kirakira
# Processing Record 2 of Set 7 | hongjiang
# Processing Record 3 of Set 7 | sisimiut
# Processing Record 4 of Set 7 | raga
# Processing Record 5 of Set 7 | esperance
# Processing Record 6 of Set 7 | pavino
# Processing Record 7 of Set 7 | zanjan
# Processing Record 8 of Set 7 | lahaina
# Processing Record 9 of Set 7 | langfang
# Processing Record 10 of Set 7 | fujin
# Processing Record 11 of Set 7 | rocha
# Processing Record 12 of Set 7 | wajid
# Processing Record 13 of Set 7 | puerto penasco
# Processing Record 14 of Set 7 | verkhnevilyuysk
# Processing Record 15 of Set 7 | kamenka
# Processing Record 16 of Set 7 | pauini
# Processing Record 17 of Set 7 | la ronge
# Processing Record 18 of Set 7 | pangody
# Processing Record 19 of Set 7 | yelan
# Processing Record 20 of Set 7 | constitucion
# Processing Record 21 of Set 7 | provideniya
# Processing Record 22 of Set 7 | okhotsk
# Processing Record 23 of Set 7 | movileni
# Processing Record 24 of Set 7 | cockburn town
# Processing Record 25 of Set 7 | mae hong son
# Processing Record 26 of Set 7 | putina
# Processing Record 27 of Set 7 | bom jesus
# Processing Record 28 of Set 7 | labuhan
# Processing Record 29 of Set 7 | vostok
# Processing Record 30 of Set 7 | kahului
# Processing Record 31 of Set 7 | sharjah
# Processing Record 32 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 7 | roma
# Processing Record 34 of Set 7 | antalaha
# Processing Record 35 of Set 7 | yima
# Processing Record 36 of Set 7 | nanortalik
# Processing Record 37 of Set 7 | iracoubo
# Processing Record 38 of Set 7 | praia
# Processing Record 39 of Set 7 | bengkulu
# Processing Record 40 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 7 | melgar
# Processing Record 42 of Set 7 | taltal
# Processing Record 43 of Set 7 | almas
# Processing Record 44 of Set 7 | bilibino
# Processing Record 45 of Set 7 | brazzaville
# Processing Record 46 of Set 7 | pangkalanbuun
# Processing Record 47 of Set 7 | belmonte
# Processing Record 48 of Set 7 | marawi
# Processing Record 49 of Set 7 | korla
# Processing Record 50 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 1 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 2 of Set 8 | oktyabrskiy
# Processing Record 3 of Set 8 | cururupu
# Processing Record 4 of Set 8 | pullman
# Processing Record 5 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 8 | vite
# Processing Record 7 of Set 8 | ukiah
# Processing Record 8 of Set 8 | kawalu
# Processing Record 9 of Set 8 | laguna
# Processing Record 10 of Set 8 | labrea
# Processing Record 11 of Set 8 | kavieng
# Processing Record 12 of Set 8 | yecla
# Processing Record 13 of Set 8 | daru
# Processing Record 14 of Set 8 | miyako
# Processing Record 15 of Set 8 | peniche
# Processing Record 16 of Set 8 | necochea
# Processing Record 17 of Set 8 | riyaq
# City not found. Skipping...
# Processing Record 18 of Set 8 | upernavik
# Processing Record 19 of Set 8 | xining
# Processing Record 20 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 8 | dhupgari
# Processing Record 22 of Set 8 | komsomolskiy
# Processing Record 23 of Set 8 | uryupinsk
# Processing Record 24 of Set 8 | assiniboia
# Processing Record 25 of Set 8 | rosetown
# Processing Record 26 of Set 8 | saint-philippe
# Processing Record 27 of Set 8 | luanda
# Processing Record 28 of Set 8 | grand gaube
# Processing Record 29 of Set 8 | gumdag
# Processing Record 30 of Set 8 | atambua
# Processing Record 31 of Set 8 | sorland
# Processing Record 32 of Set 8 | mae sai
# Processing Record 33 of Set 8 | ismailia
# Processing Record 34 of Set 8 | manono
# Processing Record 35 of Set 8 | bethel
# Processing Record 36 of Set 8 | scarborough
# Processing Record 37 of Set 8 | libreville
# Processing Record 38 of Set 8 | odweyne
# Processing Record 39 of Set 8 | trofors
# Processing Record 40 of Set 8 | lompoc
# Processing Record 41 of Set 8 | muscat
# Processing Record 42 of Set 8 | mullaitivu
# City not found. Skipping...
# Processing Record 43 of Set 8 | praia da vitoria
# Processing Record 44 of Set 8 | wajir
# Processing Record 45 of Set 8 | hvolsvollur
# Processing Record 46 of Set 8 | sao sebastiao
# Processing Record 47 of Set 8 | uwayl
# City not found. Skipping...
# Processing Record 48 of Set 8 | murray bridge
# Processing Record 49 of Set 8 | mnogovershinnyy
# Processing Record 50 of Set 8 | sitka
# Processing Record 1 of Set 9 | qaqortoq
# Processing Record 2 of Set 9 | vilhena
# Processing Record 3 of Set 9 | goderich
# Processing Record 4 of Set 9 | banes
# Processing Record 5 of Set 9 | touba
# Processing Record 6 of Set 9 | bowen
# Processing Record 7 of Set 9 | calama
# Processing Record 8 of Set 9 | siyabuswa
# Processing Record 9 of Set 9 | caluquembe
# Processing Record 10 of Set 9 | mokhotlong
# Processing Record 11 of Set 9 | tarauaca
# Processing Record 12 of Set 9 | breytovo
# Processing Record 13 of Set 9 | elliot
# Processing Record 14 of Set 9 | mongo
# Processing Record 15 of Set 9 | vardo
# Processing Record 16 of Set 9 | geraldton
# Processing Record 17 of Set 9 | christchurch
# Processing Record 18 of Set 9 | shingu
# Processing Record 19 of Set 9 | fukue
# Processing Record 20 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 9 | key west
# Processing Record 22 of Set 9 | neyshabur
# Processing Record 23 of Set 9 | airai
# Processing Record 24 of Set 9 | broome
# Processing Record 25 of Set 9 | waddan
# Processing Record 26 of Set 9 | heyang
# Processing Record 27 of Set 9 | usinsk
# Processing Record 28 of Set 9 | litoral del san juan
# City not found. Skipping...
# Processing Record 29 of Set 9 | waipawa
# Processing Record 30 of Set 9 | ialibu
# Processing Record 31 of Set 9 | shelburne
# Processing Record 32 of Set 9 | aripuana
# Processing Record 33 of Set 9 | pangnirtung
# Processing Record 34 of Set 9 | katangli
# Processing Record 35 of Set 9 | mont-dore
# Processing Record 36 of Set 9 | aquiraz
# Processing Record 37 of Set 9 | kungurtug
# Processing Record 38 of Set 9 | husavik
# Processing Record 39 of Set 9 | vanimo
# Processing Record 40 of Set 9 | kudahuvadhoo
# Processing Record 41 of Set 9 | novobiryusinskiy
# Processing Record 42 of Set 9 | porto santo
# Processing Record 43 of Set 9 | saint-michel-des-saints
# Processing Record 44 of Set 9 | muyezerskiy
# Processing Record 45 of Set 9 | sinnamary
# Processing Record 46 of Set 9 | shaunavon
# Processing Record 47 of Set 9 | guabito
# Processing Record 48 of Set 9 | aybak
# City not found. Skipping...
# Processing Record 49 of Set 9 | alofi
# Processing Record 50 of Set 9 | koslan
# Processing Record 1 of Set 10 | arlit
# Processing Record 2 of Set 10 | dilla
# Processing Record 3 of Set 10 | tulnici
# Processing Record 4 of Set 10 | mrakovo
# Processing Record 5 of Set 10 | san-pedro
# Processing Record 6 of Set 10 | atkinson
# Processing Record 7 of Set 10 | skjervoy
# Processing Record 8 of Set 10 | jawhar
# Processing Record 9 of Set 10 | kirkwall
# Processing Record 10 of Set 10 | lenggries
# Processing Record 11 of Set 10 | ulaangom
# Processing Record 12 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 10 | sistranda
# Processing Record 14 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 15 of Set 10 | kropotkin
# Processing Record 16 of Set 10 | ribeira grande
# Processing Record 17 of Set 10 | zheleznodorozhnyy
# Processing Record 18 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 19 of Set 10 | zinder
# Processing Record 20 of Set 10 | emba
# Processing Record 21 of Set 10 | san quintin
# Processing Record 22 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 10 | suwannaphum
# Processing Record 24 of Set 10 | borogontsy
# Processing Record 25 of Set 10 | northam
# Processing Record 26 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 27 of Set 10 | sola
# Processing Record 28 of Set 10 | nova olimpia
# Processing Record 29 of Set 10 | terrell
# Processing Record 30 of Set 10 | peremyshlyany
# Processing Record 31 of Set 10 | general roca
# Processing Record 32 of Set 10 | shchelyayur
# City not found. Skipping...
# Processing Record 33 of Set 10 | tikhvin
# Processing Record 34 of Set 10 | lufilufi
# Processing Record 35 of Set 10 | honningsvag
# Processing Record 36 of Set 10 | bonavista
# Processing Record 37 of Set 10 | soubre
# Processing Record 38 of Set 10 | havoysund
# Processing Record 39 of Set 10 | lagunas
# Processing Record 40 of Set 10 | darhan
# Processing Record 41 of Set 10 | grootfontein
# Processing Record 42 of Set 10 | kokologo
# Processing Record 43 of Set 10 | hachinohe
# Processing Record 44 of Set 10 | ranong
# Processing Record 45 of Set 10 | barabai
# Processing Record 46 of Set 10 | patiala
# Processing Record 47 of Set 10 | cheyenne
# Processing Record 48 of Set 10 | chuzhou
# Processing Record 49 of Set 10 | stornoway
# Processing Record 50 of Set 10 | pochutla
# Processing Record 1 of Set 11 | marsh harbour
# Processing Record 2 of Set 11 | muros
# Processing Record 3 of Set 11 | tongren
# Processing Record 4 of Set 11 | marica
# Processing Record 5 of Set 11 | grand-lahou
# Processing Record 6 of Set 11 | banjar
# Processing Record 7 of Set 11 | vila praia de ancora
# Processing Record 8 of Set 11 | valparaiso
# Processing Record 9 of Set 11 | namtsy
# Processing Record 10 of Set 11 | destin
# Processing Record 11 of Set 11 | katsuura
# Processing Record 12 of Set 11 | tekirdag
# Processing Record 13 of Set 11 | ust-uda
# Processing Record 14 of Set 11 | hot springs
# Processing Record 15 of Set 11 | ilhabela
# Processing Record 16 of Set 11 | maragogi
# Processing Record 17 of Set 11 | tsagan aman
# Processing Record 18 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 11 | kazachinskoye
# Processing Record 20 of Set 11 | arahal
# Processing Record 21 of Set 11 | oksovskiy
# Processing Record 22 of Set 11 | karratha
# Processing Record 23 of Set 11 | huarmey
# Processing Record 24 of Set 11 | narsaq
# Processing Record 25 of Set 11 | tanda
# Processing Record 26 of Set 11 | ishigaki
# Processing Record 27 of Set 11 | camacha
# Processing Record 28 of Set 11 | mildura
# Processing Record 29 of Set 11 | quatre cocos
# Processing Record 30 of Set 11 | sembe
# Processing Record 31 of Set 11 | buraydah
# Processing Record 32 of Set 11 | poltavka
# Processing Record 33 of Set 11 | natal
# Processing Record 34 of Set 11 | martapura
# Processing Record 35 of Set 11 | nishihara
# Processing Record 36 of Set 11 | jonkoping
# Processing Record 37 of Set 11 | cap-aux-meules
# Processing Record 38 of Set 11 | birao
# Processing Record 39 of Set 11 | san ramon de la nueva oran
# Processing Record 40 of Set 11 | lagos
# Processing Record 41 of Set 11 | shihezi
# Processing Record 42 of Set 11 | coihaique
# Processing Record 43 of Set 11 | matamoros
# Processing Record 44 of Set 11 | coquimbo
# Processing Record 45 of Set 11 | redlands
# Processing Record 46 of Set 11 | clearlake
# Processing Record 47 of Set 11 | novyy urengoy
# Processing Record 48 of Set 11 | kupang
# Processing Record 49 of Set 11 | sao joao da barra
# Processing Record 50 of Set 11 | cabo rojo
# Processing Record 1 of Set 12 | majene
# Processing Record 2 of Set 12 | raudeberg
# Processing Record 3 of Set 12 | evensk
# Processing Record 4 of Set 12 | mogadishu
# Processing Record 5 of Set 12 | kaltasy
# Processing Record 6 of Set 12 | kalengwa
# Processing Record 7 of Set 12 | oliver
# Processing Record 8 of Set 12 | cap malheureux
# Processing Record 9 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 10 of Set 12 | bandarbeyla
# Processing Record 11 of Set 12 | petropavlovka
# Processing Record 12 of Set 12 | lekoni
# Processing Record 13 of Set 12 | vestmanna
# Processing Record 14 of Set 12 | kailua
# Processing Record 15 of Set 12 | gorontalo
# Processing Record 16 of Set 12 | belle fourche
# Processing Record 17 of Set 12 | vao
# Processing Record 18 of Set 12 | itarema
# Processing Record 19 of Set 12 | palana
# Processing Record 20 of Set 12 | ciras
# City not found. Skipping...
# Processing Record 21 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 22 of Set 12 | druzhnaya gorka
# Processing Record 23 of Set 12 | asuncion
# Processing Record 24 of Set 12 | pathein
# Processing Record 25 of Set 12 | nampula
# Processing Record 26 of Set 12 | cabedelo
# Processing Record 27 of Set 12 | canutama
# Processing Record 28 of Set 12 | fredericksburg
# Processing Record 29 of Set 12 | roebourne
# Processing Record 30 of Set 12 | imeni poliny osipenko
# Processing Record 31 of Set 12 | klyuchi
# Processing Record 32 of Set 12 | el prat de llobregat
# Processing Record 33 of Set 12 | bathsheba
# Processing Record 34 of Set 12 | champerico
# Processing Record 35 of Set 12 | aitape
# Processing Record 36 of Set 12 | taseyevo
# Processing Record 37 of Set 12 | bulgan
# Processing Record 38 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 12 | soyo
# Processing Record 40 of Set 12 | esmeraldas
# Processing Record 41 of Set 12 | bellefontaine
# Processing Record 42 of Set 12 | megion
# Processing Record 43 of Set 12 | biak
# Processing Record 44 of Set 12 | chicama
# Processing Record 45 of Set 12 | puerto del rosario
# Processing Record 46 of Set 12 | nanakuli
# Processing Record 47 of Set 12 | yanam
# Processing Record 48 of Set 12 | port-cartier
# Processing Record 49 of Set 12 | ancud
# Processing Record 50 of Set 12 | casian
# Processing Record 1 of Set 13 | torit
# Processing Record 2 of Set 13 | lavras da mangabeira
# Processing Record 3 of Set 13 | kemijarvi
# Processing Record 4 of Set 13 | matara
# Processing Record 5 of Set 13 | puro
# Processing Record 6 of Set 13 | sovetskiy
# Processing Record 7 of Set 13 | acarau
# Processing Record 8 of Set 13 | albury
# Processing Record 9 of Set 13 | rafaela
# Processing Record 10 of Set 13 | suntar
# Processing Record 11 of Set 13 | boden
# Processing Record 12 of Set 13 | mapiripan
# Processing Record 13 of Set 13 | bambanglipuro
# Processing Record 14 of Set 13 | binzhou
# Processing Record 15 of Set 13 | yerofey pavlovich
# Processing Record 16 of Set 13 | dunmore
# Processing Record 17 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 13 | verkh-suetka
# Processing Record 19 of Set 13 | chancay
# Processing Record 20 of Set 13 | anadyr
# Processing Record 21 of Set 13 | aykhal
# Processing Record 22 of Set 13 | aksu
# Processing Record 23 of Set 13 | petatlan
# Processing Record 24 of Set 13 | erenhot
# Processing Record 25 of Set 13 | sarankhola
# Processing Record 26 of Set 13 | artyom
# Processing Record 27 of Set 13 | snezhnogorsk
# Processing Record 28 of Set 13 | alexandria
# Processing Record 29 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 13 | los llanos de aridane
# Processing Record 31 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 32 of Set 13 | dzhebariki-khaya
# Processing Record 33 of Set 13 | phan thiet
# Processing Record 34 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 13 | diffa
# Processing Record 36 of Set 13 | kaz
# Processing Record 37 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 38 of Set 13 | malinovoye ozero
# Processing Record 39 of Set 13 | kitami
# Processing Record 40 of Set 13 | rio grande
# Processing Record 41 of Set 13 | dzilam gonzalez
# Processing Record 42 of Set 13 | vila velha
# Processing Record 43 of Set 13 | shenjiamen
# Processing Record 44 of Set 13 | walvis bay
# Processing Record 45 of Set 13 | beloeil
# Processing Record 46 of Set 13 | tuensang
# Processing Record 47 of Set 13 | kinablangan
# Processing Record 48 of Set 13 | kilrush
# Processing Record 49 of Set 13 | sabzevar
# Processing Record 50 of Set 13 | kaberamaido
# Processing Record 1 of Set 14 | berlevag
# Processing Record 2 of Set 14 | porto belo
# Processing Record 3 of Set 14 | kvarkeno
# Processing Record 4 of Set 14 | houma
# Processing Record 5 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 14 | verkhnyaya inta
# Processing Record 7 of Set 14 | namatanai
# Processing Record 8 of Set 14 | puerto baquerizo moreno
# Processing Record 9 of Set 14 | chumikan
# City not found. Skipping...
# Processing Record 10 of Set 14 | kvam
# Processing Record 11 of Set 14 | lasa
# Processing Record 12 of Set 14 | charcas
# Processing Record 13 of Set 14 | constantine
# Processing Record 14 of Set 14 | iskateley
# Processing Record 15 of Set 14 | carballo
# Processing Record 16 of Set 14 | vieques
# Processing Record 17 of Set 14 | kostomuksha
# Processing Record 18 of Set 14 | mapastepec
# Processing Record 19 of Set 14 | sahrak
# City not found. Skipping...
# Processing Record 20 of Set 14 | north platte
# Processing Record 21 of Set 14 | riberalta
# Processing Record 22 of Set 14 | atyrau
# Processing Record 23 of Set 14 | ondangwa
# Processing Record 24 of Set 14 | saint-joseph
# Processing Record 25 of Set 14 | tolaga bay
# Processing Record 26 of Set 14 | krasnaya gora
# Processing Record 27 of Set 14 | tyrma
# Processing Record 28 of Set 14 | kande
# Processing Record 29 of Set 14 | auckland
# Processing Record 30 of Set 14 | toamasina
# Processing Record 31 of Set 14 | pergamino
# Processing Record 32 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 33 of Set 14 | lagoa
# Processing Record 34 of Set 14 | zhigansk
# Processing Record 35 of Set 14 | sanary-sur-mer
# Processing Record 36 of Set 14 | poddorye
# Processing Record 37 of Set 14 | pacific grove
# Processing Record 38 of Set 14 | bac lieu
# Processing Record 39 of Set 14 | tambopata
# Processing Record 40 of Set 14 | pimenta bueno
# Processing Record 41 of Set 14 | tanabe
# Processing Record 42 of Set 14 | jaramana
# City not found. Skipping...
# Processing Record 43 of Set 14 | izumo
# Processing Record 44 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 45 of Set 14 | roald
# Processing Record 46 of Set 14 | malanje
# Processing Record 47 of Set 14 | belfast
# Processing Record 48 of Set 14 | challans
# Processing Record 49 of Set 14 | moulmeingyun
# City not found. Skipping...
# Processing Record 50 of Set 14 | suoyarvi
# Processing Record 1 of Set 15 | beisfjord
# Processing Record 2 of Set 15 | ostrovnoy
# Processing Record 3 of Set 15 | novo aripuana
# Processing Record 4 of Set 15 | kapuskasing
# Processing Record 5 of Set 15 | birjand
# Processing Record 6 of Set 15 | indiana
# Processing Record 7 of Set 15 | whitehorse
# Processing Record 8 of Set 15 | nangomba
# Processing Record 9 of Set 15 | kindu
# Processing Record 10 of Set 15 | sokolka
# Processing Record 11 of Set 15 | faya
# Processing Record 12 of Set 15 | macklin
# Processing Record 13 of Set 15 | ozgon
# City not found. Skipping...
# Processing Record 14 of Set 15 | nosy varika
# Processing Record 15 of Set 15 | arman
# Processing Record 16 of Set 15 | nemuro
# Processing Record 17 of Set 15 | simao
# Processing Record 18 of Set 15 | aqtobe
# Processing Record 19 of Set 15 | urucara
# Processing Record 20 of Set 15 | methoni
# Processing Record 21 of Set 15 | ljubovija
# Processing Record 22 of Set 15 | sampit
# Processing Record 23 of Set 15 | dondo
# Processing Record 24 of Set 15 | marovoay
# Processing Record 25 of Set 15 | manzhouli
# Processing Record 26 of Set 15 | batagay-alyta
# Processing Record 27 of Set 15 | paamiut
# Processing Record 28 of Set 15 | palm coast
# Processing Record 29 of Set 15 | sapa
# Processing Record 30 of Set 15 | ruidoso
# Processing Record 31 of Set 15 | magoula
# Processing Record 32 of Set 15 | aracati
# Processing Record 33 of Set 15 | lamu
# Processing Record 34 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 35 of Set 15 | kerema
# Processing Record 36 of Set 15 | bustonkala
# City not found. Skipping...
# Processing Record 37 of Set 15 | taksimo
# Processing Record 38 of Set 15 | ust-nera
# Processing Record 39 of Set 15 | filingue
# Processing Record 40 of Set 15 | pemangkat
# Processing Record 41 of Set 15 | omboue
# Processing Record 42 of Set 15 | awjilah
# Processing Record 43 of Set 15 | coalcoman
# City not found. Skipping...
# Processing Record 44 of Set 15 | butembo
# Processing Record 45 of Set 15 | himeji
# Processing Record 46 of Set 15 | sidi ali
# Processing Record 47 of Set 15 | tutoia
# Processing Record 48 of Set 15 | strelka
# Processing Record 49 of Set 15 | naftah
# City not found. Skipping...
# Processing Record 50 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 1 of Set 16 | sobolevo
# Processing Record 2 of Set 16 | sunland park
# Processing Record 3 of Set 16 | duminichi
# Processing Record 4 of Set 16 | shimoda
# Processing Record 5 of Set 16 | riyadh
# Processing Record 6 of Set 16 | berdigestyakh
# Processing Record 7 of Set 16 | richards bay
# Processing Record 8 of Set 16 | chara
# Processing Record 9 of Set 16 | marinette
# Processing Record 10 of Set 16 | egvekinot
# Processing Record 11 of Set 16 | nyurba
# Processing Record 12 of Set 16 | shiraz
# Processing Record 13 of Set 16 | at-bashi
# Processing Record 14 of Set 16 | misratah
# Processing Record 15 of Set 16 | baishishan
# Processing Record 16 of Set 16 | stykkisholmur
# Processing Record 17 of Set 16 | zhangye
# Processing Record 18 of Set 16 | panzhihua
# Processing Record 19 of Set 16 | mahon
# Processing Record 20 of Set 16 | santa cruz do rio pardo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Khatanga      RU  71.9667  102.5000     42.42        76         100
# 1            Kutum      SD  14.2000   24.6667     77.07        54          88
# 2      New Norfolk      AU -42.7826  147.0587     46.92        77         100
# 3            Kapaa      US  22.0752 -159.3190     82.09        76          75
# 4  Arraial Do Cabo      BR -22.9661  -42.0278     67.96        73          75
# 5      Yellowknife      CA  62.4560 -114.3525     66.72        72         100
# 6          Rikitea      PF -23.1203 -134.9692     71.67        66          90
# 7        Washougal      US  45.5826 -122.3534     84.15        50           3
# 8           Ixtapa      MX  20.7000 -105.2000     86.54        77         100
# 9           Padang      ID  -0.9492  100.3543     77.18        81         100
#
#    Wind Speed Current Description
# 0        5.21     overcast clouds
# 1        1.54     overcast clouds
# 2        2.48     overcast clouds
# 3       14.97       broken clouds
# 4       11.50       broken clouds
# 5       15.01     overcast clouds
# 6       21.34          light rain
# 7        5.01           clear sky
# 8        5.44     overcast clouds
# 9        2.35       moderate rain

# %%
city_data
# Out:
# [{'City': 'Khatanga',
#   'Country': 'RU',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 42.42,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 5.21,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kutum',
#   'Country': 'SD',
#   'Lat': 14.2,
#   'Lng': 24.6667,
#   'Max Temp': 77.07,
#   'Humidity': 54,
#   'Cloudiness': 88,
#   'Wind Speed': 1.54,
#   'Current Description': 'overcast clouds'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 46.92,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 2.48,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 82.09,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Current Description': 'broken clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 67.96,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Current Description': 'broken clouds'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 66.72,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 15.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 71.67,
#   'Humidity': 66,
#   'Cloudiness': 90,
#   'Wind Speed': 21.34,
#   'Current Description': 'light rain'},
#  {'City': 'Washougal',
#   'Country': 'US',
#   'Lat': 45.5826,
#   'Lng': -122.3534,
#   'Max Temp': 84.15,
#   'Humidity': 50,
#   'Cloudiness': 3,
#   'Wind Speed': 5.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Ixtapa',
#   'Country': 'MX',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 86.54,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 5.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Padang',
#   'Country': 'ID',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 77.18,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 2.35,
#   'Current Description': 'moderate rain'},
#  {'City': 'Yar-Sale',
#   'Country': 'RU',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': 44.1,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 14.67,
#   'Current Description': 'light rain'},
#  {'City': 'Axim',
#   'Country': 'GH',
#   'Lat': 4.8699,
#   'Lng': -2.2405,
#   'Max Temp': 75.15,
#   'Humidity': 91,
#   'Cloudiness': 5,
#   'Wind Speed': 6.08,
#   'Current Description': 'clear sky'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 77.34,
#   'Humidity': 63,
#   'Cloudiness': 49,
#   'Wind Speed': 18.41,
#   'Current Description': 'scattered clouds'},
#  {'City': 'San Patricio',
#   'Country': 'US',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 77.85,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 8.7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 74.84,
#   'Humidity': 80,
#   'Cloudiness': 40,
#   'Wind Speed': 1.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 47.26,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 76.96,
#   'Humidity': 87,
#   'Cloudiness': 94,
#   'Wind Speed': 7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 81.61,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 19.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 41.49,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 8.25,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Uthal',
#   'Country': 'PK',
#   'Lat': 25.8072,
#   'Lng': 66.6219,
#   'Max Temp': 79.86,
#   'Humidity': 84,
#   'Cloudiness': 41,
#   'Wind Speed': 7.27,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 82.04,
#   'Humidity': 76,
#   'Cloudiness': 3,
#   'Wind Speed': 16.46,
#   'Current Description': 'clear sky'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 39.31,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 12.66,
#   'Current Description': 'moderate rain'},
#  {'City': 'Hualmay',
#   'Country': 'PE',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 65.7,
#   'Humidity': 69,
#   'Cloudiness': 17,
#   'Wind Speed': 7.18,
#   'Current Description': 'few clouds'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 41.81,
#   'Humidity': 70,
#   'Cloudiness': 79,
#   'Wind Speed': 22.24,
#   'Current Description': 'broken clouds'},
#  {'City': 'Lithgow',
#   'Country': 'AU',
#   'Lat': -33.4833,
#   'Lng': 150.15,
#   'Max Temp': 32.49,
#   'Humidity': 96,
#   'Cloudiness': 3,
#   'Wind Speed': 1.72,
#   'Current Description': 'clear sky'},
#  {'City': 'Kavaratti',
#   'Country': 'IN',
#   'Lat': 10.5669,
#   'Lng': 72.642,
#   'Max Temp': 80.76,
#   'Humidity': 82,
#   'Cloudiness': 33,
#   'Wind Speed': 24.05,
#   'Current Description': 'moderate rain'},
#  {'City': 'Charleston',
#   'Country': 'US',
#   'Lat': 32.7766,
#   'Lng': -79.9309,
#   'Max Temp': 89.33,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Vila',
#   'Country': 'PT',
#   'Lat': 42.0304,
#   'Lng': -8.1588,
#   'Max Temp': 56.28,
#   'Humidity': 90,
#   'Cloudiness': 87,
#   'Wind Speed': 5.68,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kaitangata',
#   'Country': 'NZ',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 36.5,
#   'Humidity': 85,
#   'Cloudiness': 81,
#   'Wind Speed': 15.3,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hami',
#   'Country': 'CN',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 74.41,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 5.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Erzin',
#   'Country': 'TR',
#   'Lat': 36.9559,
#   'Lng': 36.2,
#   'Max Temp': 75.49,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 0.87,
#   'Current Description': 'clear sky'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 84.27,
#   'Humidity': 81,
#   'Cloudiness': 21,
#   'Wind Speed': 4,
#   'Current Description': 'few clouds'},
#  {'City': 'Cabo San Lucas',
#   'Country': 'MX',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 94.6,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 6.31,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Leshukonskoye',
#   'Country': 'RU',
#   'Lat': 64.8989,
#   'Lng': 45.7622,
#   'Max Temp': 42.62,
#   'Humidity': 89,
#   'Cloudiness': 93,
#   'Wind Speed': 7.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 78.96,
#   'Humidity': 47,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Dunedin',
#   'Country': 'NZ',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 39.79,
#   'Humidity': 74,
#   'Cloudiness': 94,
#   'Wind Speed': 8.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Okha',
#   'Country': 'RU',
#   'Lat': 53.5739,
#   'Lng': 142.9478,
#   'Max Temp': 56.88,
#   'Humidity': 93,
#   'Cloudiness': 82,
#   'Wind Speed': 5.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 54.25,
#   'Humidity': 73,
#   'Cloudiness': 21,
#   'Wind Speed': 14.88,
#   'Current Description': 'few clouds'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 38.8,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 7.52,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Hedland',
#   'Country': 'AU',
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp': 62.65,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Mehamn',
#   'Country': 'NO',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 48.11,
#   'Humidity': 81,
#   'Cloudiness': 96,
#   'Wind Speed': 21.59,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chifeng',
#   'Country': 'CN',
#   'Lat': 42.2683,
#   'Lng': 118.9636,
#   'Max Temp': 53.73,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 15.77,
#   'Current Description': 'clear sky'},
#  {'City': 'Mizan Teferi',
#   'Country': 'ET',
#   'Lat': 6.9833,
#   'Lng': 35.5833,
#   'Max Temp': 60.17,
#   'Humidity': 97,
#   'Cloudiness': 74,
#   'Wind Speed': 1.52,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 68.16,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Current Description': 'few clouds'},
#  {'City': 'Barnala',
#   'Country': 'IN',
#   'Lat': 30.3833,
#   'Lng': 75.55,
#   'Max Temp': 79.65,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 7.27,
#   'Current Description': 'clear sky'},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 67.93,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 5.55,
#   'Current Description': 'clear sky'},
#  {'City': 'Asau',
#   'Country': 'RO',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 56.32,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 0.89,
#   'Current Description': 'light rain'},
#  {'City': 'Coolum Beach',
#   'Country': 'AU',
#   'Lat': -26.5333,
#   'Lng': 153.1,
#   'Max Temp': 55.11,
#   'Humidity': 78,
#   'Cloudiness': 34,
#   'Wind Speed': 11.59,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 48.78,
#   'Humidity': 92,
#   'Cloudiness': 98,
#   'Wind Speed': 5.19,
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Juan',
#   'Country': 'AR',
#   'Lat': -31.5375,
#   'Lng': -68.5364,
#   'Max Temp': 75.22,
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 4.9,
#   'Current Description': 'clear sky'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 42.46,
#   'Humidity': 52,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Medicine Hat',
#   'Country': 'CA',
#   'Lat': 50.0501,
#   'Lng': -110.6683,
#   'Max Temp': 85.84,
#   'Humidity': 26,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Current Description': 'smoke'},
#  {'City': 'Fortuna',
#   'Country': 'US',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 74.93,
#   'Humidity': 70,
#   'Cloudiness': 22,
#   'Wind Speed': 5.99,
#   'Current Description': 'few clouds'},
#  {'City': 'Bourail',
#   'Country': 'NC',
#   'Lat': -21.5667,
#   'Lng': 165.4833,
#   'Max Temp': 70.83,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 8.99,
#   'Current Description': 'light rain'},
#  {'City': 'Sept-Iles',
#   'Country': 'CA',
#   'Lat': 50.2001,
#   'Lng': -66.3821,
#   'Max Temp': 64.92,
#   'Humidity': 54,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Current Description': 'broken clouds'},
#  {'City': 'Luderitz',
#   'Country': 'NA',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 57.02,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 0.87,
#   'Current Description': 'clear sky'},
#  {'City': 'Pappadatai',
#   'Country': 'GR',
#   'Lat': 39.3133,
#   'Lng': 20.7925,
#   'Max Temp': 75.83,
#   'Humidity': 68,
#   'Cloudiness': 15,
#   'Wind Speed': 0.54,
#   'Current Description': 'few clouds'},
#  {'City': 'Shamary',
#   'Country': 'RU',
#   'Lat': 57.3434,
#   'Lng': 58.2199,
#   'Max Temp': 40.66,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 3.76,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kaeo',
#   'Country': 'NZ',
#   'Lat': -35.1,
#   'Lng': 173.7833,
#   'Max Temp': 58.32,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 15.84,
#   'Current Description': 'light rain'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 55.65,
#   'Humidity': 84,
#   'Cloudiness': 43,
#   'Wind Speed': 10.96,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tuatapere',
#   'Country': 'NZ',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 38.19,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 15.84,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 61.18,
#   'Humidity': 70,
#   'Cloudiness': 5,
#   'Wind Speed': 1.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Hasaki',
#   'Country': 'JP',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 73.8,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 9.26,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Juruti',
#   'Country': 'BR',
#   'Lat': -2.1522,
#   'Lng': -56.0922,
#   'Max Temp': 95.32,
#   'Humidity': 34,
#   'Cloudiness': 62,
#   'Wind Speed': 5.86,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kruisfontein',
#   'Country': 'ZA',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 57.16,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 9.13,
#   'Current Description': 'clear sky'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 56.37,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Current Description': 'moderate rain'},
#  {'City': 'Clyde River',
#   'Country': 'CA',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 41.23,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 12.66,
#   'Current Description': 'light rain'},
#  {'City': 'Mount Isa',
#   'Country': 'AU',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 46.17,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Am Timan',
#   'Country': 'TD',
#   'Lat': 11.0297,
#   'Lng': 20.2827,
#   'Max Temp': 72.05,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 3.15,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Faanui',
#   'Country': 'PF',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 78.6,
#   'Humidity': 72,
#   'Cloudiness': 99,
#   'Wind Speed': 18.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Black River',
#   'Country': 'JM',
#   'Lat': 18.0264,
#   'Lng': -77.8487,
#   'Max Temp': 85.41,
#   'Humidity': 66,
#   'Cloudiness': 76,
#   'Wind Speed': 5.39,
#   'Current Description': 'moderate rain'},
#  {'City': 'Angoram',
#   'Country': 'PG',
#   'Lat': -4.0625,
#   'Lng': 144.0661,
#   'Max Temp': 72.36,
#   'Humidity': 99,
#   'Cloudiness': 77,
#   'Wind Speed': 1.97,
#   'Current Description': 'broken clouds'},
#  {'City': 'Makakilo City',
#   'Country': 'US',
#   'Lat': 21.3469,
#   'Lng': -158.0858,
#   'Max Temp': 83.01,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 12.66,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 39.61,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 4.74,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Camargo',
#   'Country': 'MX',
#   'Lat': 27.6667,
#   'Lng': -105.1667,
#   'Max Temp': 78.87,
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 7.87,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tarko-Sale',
#   'Country': 'RU',
#   'Lat': 64.9225,
#   'Lng': 77.785,
#   'Max Temp': 44.42,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 15.64,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Koroni',
#   'Country': 'GR',
#   'Lat': 36.8,
#   'Lng': 21.95,
#   'Max Temp': 81.07,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 7.65,
#   'Current Description': 'clear sky'},
#  {'City': 'Souillac',
#   'Country': 'MU',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 70.18,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sao Filipe',
#   'Country': 'CV',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 80.46,
#   'Humidity': 82,
#   'Cloudiness': 88,
#   'Wind Speed': 5.75,
#   'Current Description': 'light rain'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 64.83,
#   'Humidity': 63,
#   'Cloudiness': 8,
#   'Wind Speed': 10.98,
#   'Current Description': 'clear sky'},
#  {'City': 'Masvingo',
#   'Country': 'ZW',
#   'Lat': -20.0637,
#   'Lng': 30.8277,
#   'Max Temp': 62.53,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 5.39,
#   'Current Description': 'clear sky'},
#  {'City': 'Lavrentiya',
#   'Country': 'RU',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 38.77,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 9.95,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 53.62,
#   'Humidity': 94,
#   'Cloudiness': 77,
#   'Wind Speed': 8.19,
#   'Current Description': 'broken clouds'},
#  {'City': 'Cherskiy',
#   'Country': 'RU',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 36.36,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind Speed': 7.63,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ternate',
#   'Country': 'ID',
#   'Lat': 0.8,
#   'Lng': 127.4,
#   'Max Temp': 79.09,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 4.25,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kaniama',
#   'Country': 'CD',
#   'Lat': -7.5667,
#   'Lng': 24.1833,
#   'Max Temp': 72.03,
#   'Humidity': 72,
#   'Cloudiness': 23,
#   'Wind Speed': 0.92,
#   'Current Description': 'few clouds'},
#  {'City': 'Aksha',
#   'Country': 'RU',
#   'Lat': 50.2814,
#   'Lng': 113.2867,
#   'Max Temp': 37.94,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 13.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sabang',
#   'Country': 'ID',
#   'Lat': 5.8933,
#   'Lng': 95.3214,
#   'Max Temp': 81.64,
#   'Humidity': 71,
#   'Cloudiness': 99,
#   'Wind Speed': 17.07,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bonthe',
#   'Country': 'SL',
#   'Lat': 7.5264,
#   'Lng': -12.505,
#   'Max Temp': 77.43,
#   'Humidity': 85,
#   'Cloudiness': 29,
#   'Wind Speed': 5.44,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Pevek',
#   'Country': 'RU',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 34.12,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 3.87,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bilma',
#   'Country': 'NE',
#   'Lat': 18.6853,
#   'Lng': 12.9164,
#   'Max Temp': 97.07,
#   'Humidity': 16,
#   'Cloudiness': 62,
#   'Wind Speed': 4.14,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bentiu',
#   'Country': 'SS',
#   'Lat': 9.2333,
#   'Lng': 29.8333,
#   'Max Temp': 71.94,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 1.81,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Thomastown',
#   'Country': 'IE',
#   'Lat': 52.5267,
#   'Lng': -7.1372,
#   'Max Temp': 63.43,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 13.76,
#   'Current Description': 'light rain'},
#  {'City': 'Torbay',
#   'Country': 'CA',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 69.17,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Alyangula',
#   'Country': 'AU',
#   'Lat': -13.8483,
#   'Lng': 136.4192,
#   'Max Temp': 57.07,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Current Description': 'fog'},
#  {'City': 'Keti Bandar',
#   'Country': 'PK',
#   'Lat': 24.1447,
#   'Lng': 67.4497,
#   'Max Temp': 81.43,
#   'Humidity': 77,
#   'Cloudiness': 98,
#   'Wind Speed': 21.56,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ponta Delgada',
#   'Country': 'PT',
#   'Lat': 37.7333,
#   'Lng': -25.6667,
#   'Max Temp': 74.12,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Current Description': 'few clouds'},
#  {'City': 'Antofagasta',
#   'Country': 'CL',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 58.28,
#   'Humidity': 65,
#   'Cloudiness': 14,
#   'Wind Speed': 6.89,
#   'Current Description': 'few clouds'},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 42.53,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 20.71,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 51.8,
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 26.96,
#   'Current Description': 'light rain'},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 76.01,
#   'Humidity': 76,
#   'Cloudiness': 51,
#   'Wind Speed': 4.56,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ugoofaaru',
#   'Country': 'MV',
#   'Lat': 5.6667,
#   'Lng': 73,
#   'Max Temp': 79.45,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 24.87,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Maniitsoq',
#   'Country': 'GL',
#   'Lat': 65.4167,
#   'Lng': -52.9,
#   'Max Temp': 45.66,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 12.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Obera',
#   'Country': 'AR',
#   'Lat': -27.4871,
#   'Lng': -55.1199,
#   'Max Temp': 62.49,
#   'Humidity': 44,
#   'Cloudiness': 72,
#   'Wind Speed': 4.09,
#   'Current Description': 'broken clouds'},
#  {'City': 'Pisco',
#   'Country': 'PE',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 63.01,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Current Description': 'mist'},
#  {'City': 'Margate',
#   'Country': 'GB',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 68.31,
#   'Humidity': 75,
#   'Cloudiness': 91,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Zyryanka',
#   'Country': 'RU',
#   'Lat': 65.75,
#   'Lng': 150.85,
#   'Max Temp': 34.38,
#   'Humidity': 75,
#   'Cloudiness': 92,
#   'Wind Speed': 6.78,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saldanha',
#   'Country': 'ZA',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 53.65,
#   'Humidity': 76,
#   'Cloudiness': 8,
#   'Wind Speed': 23.47,
#   'Current Description': 'light rain'},
#  {'City': 'Trairi',
#   'Country': 'BR',
#   'Lat': -3.2778,
#   'Lng': -39.2689,
#   'Max Temp': 80.42,
#   'Humidity': 75,
#   'Cloudiness': 79,
#   'Wind Speed': 16.8,
#   'Current Description': 'broken clouds'},
#  {'City': 'Dickinson',
#   'Country': 'US',
#   'Lat': 29.4608,
#   'Lng': -95.0513,
#   'Max Temp': 83.16,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 7.43,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 83.39,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 2.35,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Igarka',
#   'Country': 'RU',
#   'Lat': 67.4667,
#   'Lng': 86.5833,
#   'Max Temp': 42.91,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Skibbereen',
#   'Country': 'IE',
#   'Lat': 51.55,
#   'Lng': -9.2667,
#   'Max Temp': 60.12,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 17.29,
#   'Current Description': 'light rain'},
#  {'City': 'Te Anau',
#   'Country': 'NZ',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 32.36,
#   'Humidity': 95,
#   'Cloudiness': 78,
#   'Wind Speed': 0.45,
#   'Current Description': 'broken clouds'},
#  {'City': 'Huilong',
#   'Country': 'CN',
#   'Lat': 31.8111,
#   'Lng': 121.655,
#   'Max Temp': 76.93,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 21.27,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Svencioneliai',
#   'Country': 'LT',
#   'Lat': 55.1667,
#   'Lng': 26,
#   'Max Temp': 46.4,
#   'Humidity': 88,
#   'Cloudiness': 99,
#   'Wind Speed': 5.48,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 51.8,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 12.66,
#   'Current Description': 'light rain'},
#  {'City': 'Rudnya',
#   'Country': 'RU',
#   'Lat': 54.947,
#   'Lng': 31.0934,
#   'Max Temp': 45.81,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rawson',
#   'Country': 'AR',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 66.54,
#   'Humidity': 34,
#   'Cloudiness': 57,
#   'Wind Speed': 6.24,
#   'Current Description': 'broken clouds'},
#  {'City': 'Boende',
#   'Country': 'CD',
#   'Lat': -0.2167,
#   'Lng': 20.8667,
#   'Max Temp': 71.46,
#   'Humidity': 93,
#   'Cloudiness': 81,
#   'Wind Speed': 2.77,
#   'Current Description': 'light rain'},
#  {'City': 'Namibe',
#   'Country': 'AO',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 62.4,
#   'Humidity': 90,
#   'Cloudiness': 45,
#   'Wind Speed': 8.37,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Saint-Pierre',
#   'Country': 'RE',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 71.28,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Current Description': 'clear sky'},
#  {'City': 'Ocampo',
#   'Country': 'MX',
#   'Lat': 21.65,
#   'Lng': -101.5,
#   'Max Temp': 71.58,
#   'Humidity': 49,
#   'Cloudiness': 20,
#   'Wind Speed': 19.01,
#   'Current Description': 'few clouds'},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 37.26,
#   'Humidity': 73,
#   'Cloudiness': 98,
#   'Wind Speed': 17.65,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cidreira',
#   'Country': 'BR',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 59.76,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 8.1,
#   'Current Description': 'clear sky'},
#  {'City': 'Amapa',
#   'Country': 'BR',
#   'Lat': 1,
#   'Lng': -52,
#   'Max Temp': 77.16,
#   'Humidity': 75,
#   'Cloudiness': 84,
#   'Wind Speed': 3.04,
#   'Current Description': 'moderate rain'},
#  {'City': 'Blenheim',
#   'Country': 'NZ',
#   'Lat': -41.516,
#   'Lng': 173.9528,
#   'Max Temp': 42.53,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 6.11,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Maicao',
#   'Country': 'CO',
#   'Lat': 11.3832,
#   'Lng': -72.2432,
#   'Max Temp': 88.34,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 10.31,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Songjianghe',
#   'Country': 'CN',
#   'Lat': 42.1859,
#   'Lng': 127.479,
#   'Max Temp': 50.52,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 4.41,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Eyl',
#   'Country': 'SO',
#   'Lat': 7.9803,
#   'Lng': 49.8164,
#   'Max Temp': 76.71,
#   'Humidity': 81,
#   'Cloudiness': 11,
#   'Wind Speed': 25.81,
#   'Current Description': 'few clouds'},
#  {'City': 'Hope',
#   'Country': 'US',
#   'Lat': 33.6671,
#   'Lng': -93.5916,
#   'Max Temp': 89.98,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 2.39,
#   'Current Description': 'clear sky'},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 80.89,
#   'Humidity': 90,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Current Description': 'light rain'},
#  {'City': 'Isangel',
#   'Country': 'VU',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 76.84,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 9.15,
#   'Current Description': 'light rain'},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 102.25,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 5.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Adrar',
#   'Country': 'MR',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 99.37,
#   'Humidity': 22,
#   'Cloudiness': 22,
#   'Wind Speed': 9.82,
#   'Current Description': 'few clouds'},
#  {'City': 'Oranjestad',
#   'Country': 'AW',
#   'Lat': 12.524,
#   'Lng': -70.027,
#   'Max Temp': 89.55,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Current Description': 'few clouds'},
#  {'City': 'Noumea',
#   'Country': 'NC',
#   'Lat': -22.2763,
#   'Lng': 166.4572,
#   'Max Temp': 75.99,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 17.9,
#   'Current Description': 'light rain'},
#  {'City': 'Leningradskiy',
#   'Country': 'RU',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': 35.11,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Boulder City',
#   'Country': 'US',
#   'Lat': 35.9786,
#   'Lng': -114.8325,
#   'Max Temp': 104.94,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Ghanzi',
#   'Country': 'BW',
#   'Lat': -21.5667,
#   'Lng': 21.7833,
#   'Max Temp': 67.21,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 4.76,
#   'Current Description': 'clear sky'},
#  {'City': 'Baruun-Urt',
#   'Country': 'MN',
#   'Lat': 46.6806,
#   'Lng': 113.2792,
#   'Max Temp': 35.38,
#   'Humidity': 77,
#   'Cloudiness': 48,
#   'Wind Speed': 17.07,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 50.65,
#   'Humidity': 77,
#   'Cloudiness': 36,
#   'Wind Speed': 18.84,
#   'Current Description': 'light rain'},
#  {'City': 'Adre',
#   'Country': 'TD',
#   'Lat': 13.4667,
#   'Lng': 22.2,
#   'Max Temp': 73.15,
#   'Humidity': 80,
#   'Cloudiness': 65,
#   'Wind Speed': 5.55,
#   'Current Description': 'broken clouds'},
#  {'City': 'Camocim',
#   'Country': 'BR',
#   'Lat': -2.9022,
#   'Lng': -40.8411,
#   'Max Temp': 84.63,
#   'Humidity': 64,
#   'Cloudiness': 16,
#   'Wind Speed': 21.63,
#   'Current Description': 'few clouds'},
#  {'City': 'Rio Tuba',
#   'Country': 'PH',
#   'Lat': 8.5061,
#   'Lng': 117.4317,
#   'Max Temp': 80.46,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 11.88,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Oistins',
#   'Country': 'BB',
#   'Lat': 13.0667,
#   'Lng': -59.5333,
#   'Max Temp': 86.09,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Machiques',
#   'Country': 'VE',
#   'Lat': 10.0644,
#   'Lng': -72.545,
#   'Max Temp': 87.67,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 2.71,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kushalgarh',
#   'Country': 'IN',
#   'Lat': 23.199,
#   'Lng': 74.4507,
#   'Max Temp': 76.06,
#   'Humidity': 91,
#   'Cloudiness': 79,
#   'Wind Speed': 6.4,
#   'Current Description': 'broken clouds'},
#  {'City': 'Aklavik',
#   'Country': 'CA',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': 50,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Manta',
#   'Country': 'EC',
#   'Lat': -0.95,
#   'Lng': -80.7333,
#   'Max Temp': 85.78,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Kurumkan',
#   'Country': 'RU',
#   'Lat': 54.3,
#   'Lng': 110.3,
#   'Max Temp': 41.16,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 3.15,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Touros',
#   'Country': 'BR',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 76.87,
#   'Humidity': 84,
#   'Cloudiness': 24,
#   'Wind Speed': 12.97,
#   'Current Description': 'few clouds'},
#  {'City': 'Iki-Burul',
#   'Country': 'RU',
#   'Lat': 45.8208,
#   'Lng': 44.6472,
#   'Max Temp': 67.48,
#   'Humidity': 47,
#   'Cloudiness': 36,
#   'Wind Speed': 12.62,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Peleduy',
#   'Country': 'RU',
#   'Lat': 59.6289,
#   'Lng': 112.7406,
#   'Max Temp': 34.41,
#   'Humidity': 98,
#   'Cloudiness': 21,
#   'Wind Speed': 2.3,
#   'Current Description': 'few clouds'},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 35.67,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 14.29,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sao Jose Da Coroa Grande',
#   'Country': 'BR',
#   'Lat': -8.8978,
#   'Lng': -35.1478,
#   'Max Temp': 75.43,
#   'Humidity': 82,
#   'Cloudiness': 91,
#   'Wind Speed': 11.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bambous Virieux',
#   'Country': 'MU',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 70.21,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Srednekolymsk',
#   'Country': 'RU',
#   'Lat': 67.45,
#   'Lng': 153.6833,
#   'Max Temp': 35.58,
#   'Humidity': 83,
#   'Cloudiness': 89,
#   'Wind Speed': 9.89,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Khambhaliya',
#   'Country': 'IN',
#   'Lat': 22.2072,
#   'Lng': 69.6683,
#   'Max Temp': 81.3,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 14.76,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rockhampton',
#   'Country': 'AU',
#   'Lat': -23.3833,
#   'Lng': 150.5,
#   'Max Temp': 57.09,
#   'Humidity': 94,
#   'Cloudiness': 71,
#   'Wind Speed': 6.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Atar',
#   'Country': 'MR',
#   'Lat': 20.5169,
#   'Lng': -13.0499,
#   'Max Temp': 100.06,
#   'Humidity': 25,
#   'Cloudiness': 58,
#   'Wind Speed': 8.7,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ullapool',
#   'Country': 'GB',
#   'Lat': 57.8987,
#   'Lng': -5.1604,
#   'Max Temp': 63.36,
#   'Humidity': 95,
#   'Cloudiness': 36,
#   'Wind Speed': 6.6,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Guerrero Negro',
#   'Country': 'MX',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 86.32,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 10.4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Santa Isabel Do Rio Negro',
#   'Country': 'BR',
#   'Lat': -0.4139,
#   'Lng': -65.0192,
#   'Max Temp': 83.05,
#   'Humidity': 69,
#   'Cloudiness': 57,
#   'Wind Speed': 6.67,
#   'Current Description': 'broken clouds'},
#  {'City': 'Caravelas',
#   'Country': 'BR',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 74.23,
#   'Humidity': 72,
#   'Cloudiness': 5,
#   'Wind Speed': 6.98,
#   'Current Description': 'clear sky'},
#  {'City': 'Iralaya',
#   'Country': 'HN',
#   'Lat': 15,
#   'Lng': -83.2333,
#   'Max Temp': 83.88,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 7.92,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hamilton',
#   'Country': 'US',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 83.52,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 75.25,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Current Description': 'few clouds'},
#  {'City': 'Mayo',
#   'Country': 'US',
#   'Lat': 38.8876,
#   'Lng': -76.5119,
#   'Max Temp': 91.36,
#   'Humidity': 63,
#   'Cloudiness': 31,
#   'Wind Speed': 4,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tura',
#   'Country': 'IN',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 73.47,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Talnakh',
#   'Country': 'RU',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 43.21,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 4.88,
#   'Current Description': 'light rain'},
#  {'City': 'Ormara',
#   'Country': 'PK',
#   'Lat': 25.2088,
#   'Lng': 64.6357,
#   'Max Temp': 79.99,
#   'Humidity': 82,
#   'Cloudiness': 62,
#   'Wind Speed': 16.6,
#   'Current Description': 'broken clouds'},
#  {'City': 'Fare',
#   'Country': 'PF',
#   'Lat': -16.7,
#   'Lng': -151.0167,
#   'Max Temp': 78.69,
#   'Humidity': 70,
#   'Cloudiness': 4,
#   'Wind Speed': 16.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Longyearbyen',
#   'Country': 'SJ',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 40.84,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Current Description': 'light intensity drizzle rain'},
#  {'City': 'Urumqi',
#   'Country': 'CN',
#   'Lat': 43.801,
#   'Lng': 87.6005,
#   'Max Temp': 70.75,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Current Description': 'clear sky'},
#  {'City': 'Gornopravdinsk',
#   'Country': 'RU',
#   'Lat': 60.05,
#   'Lng': 69.9,
#   'Max Temp': 44.31,
#   'Humidity': 75,
#   'Cloudiness': 11,
#   'Wind Speed': 10.09,
#   'Current Description': 'few clouds'},
#  {'City': 'Norman Wells',
#   'Country': 'CA',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 59.04,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Altamont',
#   'Country': 'US',
#   'Lat': 42.2068,
#   'Lng': -121.7372,
#   'Max Temp': 85.78,
#   'Humidity': 25,
#   'Cloudiness': 8,
#   'Wind Speed': 3,
#   'Current Description': 'clear sky'},
#  {'City': 'Shinuhayr',
#   'Country': 'AM',
#   'Lat': 39.4367,
#   'Lng': 46.3179,
#   'Max Temp': 66.67,
#   'Humidity': 29,
#   'Cloudiness': 9,
#   'Wind Speed': 2.04,
#   'Current Description': 'clear sky'},
#  {'City': 'Parker',
#   'Country': 'US',
#   'Lat': 32.7668,
#   'Lng': -97.8003,
#   'Max Temp': 96.58,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Casper',
#   'Country': 'US',
#   'Lat': 42.8666,
#   'Lng': -106.3131,
#   'Max Temp': 97.72,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 8.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Kulu',
#   'Country': 'TR',
#   'Lat': 39.0951,
#   'Lng': 33.0799,
#   'Max Temp': 72.59,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 9.78,
#   'Current Description': 'clear sky'},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 70.25,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Avera',
#   'Country': 'US',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 81.91,
#   'Humidity': 59,
#   'Cloudiness': 76,
#   'Wind Speed': 8.28,
#   'Current Description': 'broken clouds'},
#  {'City': 'Carbonia',
#   'Country': 'IT',
#   'Lat': 39.1672,
#   'Lng': 8.5222,
#   'Max Temp': 82,
#   'Humidity': 42,
#   'Cloudiness': 5,
#   'Wind Speed': 5.48,
#   'Current Description': 'clear sky'},
#  {'City': 'Port Moresby',
#   'Country': 'PG',
#   'Lat': -9.4431,
#   'Lng': 147.1797,
#   'Max Temp': 76.42,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Zhezkazgan',
#   'Country': 'KZ',
#   'Lat': 47.8043,
#   'Lng': 67.7144,
#   'Max Temp': 78.15,
#   'Humidity': 36,
#   'Cloudiness': 1,
#   'Wind Speed': 8.57,
#   'Current Description': 'clear sky'},
#  {'City': 'Krasnoarmeysk',
#   'Country': 'RU',
#   'Lat': 51.0239,
#   'Lng': 45.6969,
#   'Max Temp': 47.98,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 14.27,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nouakchott',
#   'Country': 'MR',
#   'Lat': 18.0858,
#   'Lng': -15.9785,
#   'Max Temp': 89.53,
#   'Humidity': 71,
#   'Cloudiness': 28,
#   'Wind Speed': 7.58,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Alice Springs',
#   'Country': 'AU',
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp': 36.95,
#   'Humidity': 93,
#   'Cloudiness': 22,
#   'Wind Speed': 4.61,
#   'Current Description': 'few clouds'},
#  {'City': 'Safford',
#   'Country': 'US',
#   'Lat': 32.834,
#   'Lng': -109.7076,
#   'Max Temp': 89.11,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 8.28,
#   'Current Description': 'clear sky'},
#  {'City': 'Nouadhibou',
#   'Country': 'MR',
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp': 84.18,
#   'Humidity': 61,
#   'Cloudiness': 18,
#   'Wind Speed': 13.8,
#   'Current Description': 'few clouds'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 40.93,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 10.58,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lorengau',
#   'Country': 'PG',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 81.45,
#   'Humidity': 70,
#   'Cloudiness': 12,
#   'Wind Speed': 10.54,
#   'Current Description': 'few clouds'},
#  {'City': 'Ilulissat',
#   'Country': 'GL',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 46.04,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 7.49,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aginskoye',
#   'Country': 'RU',
#   'Lat': 51.1,
#   'Lng': 114.53,
#   'Max Temp': 45.21,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 9.71,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Presidencia Roque Saenz Pena',
#   'Country': 'AR',
#   'Lat': -26.7852,
#   'Lng': -60.4388,
#   'Max Temp': 74.14,
#   'Humidity': 12,
#   'Cloudiness': 3,
#   'Wind Speed': 7.76,
#   'Current Description': 'clear sky'},
#  {'City': 'Altoona',
#   'Country': 'US',
#   'Lat': 40.5187,
#   'Lng': -78.3947,
#   'Max Temp': 86.83,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 1.32,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nago',
#   'Country': 'JP',
#   'Lat': 26.5881,
#   'Lng': 127.9761,
#   'Max Temp': 79.23,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 28.97,
#   'Current Description': 'moderate rain'},
#  {'City': 'Chilliwack',
#   'Country': 'CA',
#   'Lat': 49.1747,
#   'Lng': -121.9443,
#   'Max Temp': 71.78,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bata',
#   'Country': 'GQ',
#   'Lat': 1.8639,
#   'Lng': 9.7658,
#   'Max Temp': 76.42,
#   'Humidity': 86,
#   'Cloudiness': 14,
#   'Wind Speed': 9.95,
#   'Current Description': 'few clouds'},
#  {'City': 'Yeppoon',
#   'Country': 'AU',
#   'Lat': -23.1333,
#   'Lng': 150.7333,
#   'Max Temp': 56.98,
#   'Humidity': 83,
#   'Cloudiness': 27,
#   'Wind Speed': 13.44,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hirara',
#   'Country': 'JP',
#   'Lat': 24.8,
#   'Lng': 125.2833,
#   'Max Temp': 82.27,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 39.71,
#   'Current Description': 'moderate rain'},
#  {'City': 'Bud',
#   'Country': 'US',
#   'Lat': 39.447,
#   'Lng': -86.1758,
#   'Max Temp': 83.05,
#   'Humidity': 76,
#   'Cloudiness': 95,
#   'Wind Speed': 5.64,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vila Franca Do Campo',
#   'Country': 'PT',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 73.81,
#   'Humidity': 74,
#   'Cloudiness': 2,
#   'Wind Speed': 7.78,
#   'Current Description': 'clear sky'},
#  {'City': 'Beringovskiy',
#   'Country': 'RU',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 50.85,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 8.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 52.68,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 1.43,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Payakumbuh',
#   'Country': 'ID',
#   'Lat': -0.2202,
#   'Lng': 100.6308,
#   'Max Temp': 70.16,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 3.02,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bafq',
#   'Country': 'IR',
#   'Lat': 31.6128,
#   'Lng': 55.4107,
#   'Max Temp': 81.45,
#   'Humidity': 10,
#   'Cloudiness': 0,
#   'Wind Speed': 0.94,
#   'Current Description': 'clear sky'},
#  {'City': 'Seddon',
#   'Country': 'AU',
#   'Lat': -37.8068,
#   'Lng': 144.8916,
#   'Max Temp': 48.38,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Current Description': 'broken clouds'},
#  {'City': 'Port Macquarie',
#   'Country': 'AU',
#   'Lat': -31.4333,
#   'Lng': 152.9167,
#   'Max Temp': 47.89,
#   'Humidity': 77,
#   'Cloudiness': 99,
#   'Wind Speed': 11.1,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hofn',
#   'Country': 'IS',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 49.87,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 9.73,
#   'Current Description': 'clear sky'},
#  {'City': 'Knysna',
#   'Country': 'ZA',
#   'Lat': -34.0363,
#   'Lng': 23.0471,
#   'Max Temp': 56.75,
#   'Humidity': 81,
#   'Cloudiness': 88,
#   'Wind Speed': 9.31,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Portland',
#   'Country': 'US',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 83.61,
#   'Humidity': 51,
#   'Cloudiness': 6,
#   'Wind Speed': 5.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Chuy',
#   'Country': 'UY',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 60.93,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 2.53,
#   'Current Description': 'clear sky'},
#  {'City': 'Guilin',
#   'Country': 'CN',
#   'Lat': 25.2819,
#   'Lng': 110.2864,
#   'Max Temp': 68.11,
#   'Humidity': 65,
#   'Cloudiness': 68,
#   'Wind Speed': 3.62,
#   'Current Description': 'broken clouds'},
#  {'City': 'Acapulco',
#   'Country': 'MX',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 78.78,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 18.3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Codrington',
#   'Country': 'AU',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 47.48,
#   'Humidity': 81,
#   'Cloudiness': 61,
#   'Wind Speed': 10.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Koumac',
#   'Country': 'NC',
#   'Lat': -20.5667,
#   'Lng': 164.2833,
#   'Max Temp': 72.55,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 11.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Salinas',
#   'Country': 'US',
#   'Lat': 36.6777,
#   'Lng': -121.6555,
#   'Max Temp': 106.02,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 6.64,
#   'Current Description': 'clear sky'},
#  {'City': 'Esil',
#   'Country': 'KZ',
#   'Lat': 51.9556,
#   'Lng': 66.4042,
#   'Max Temp': 61.56,
#   'Humidity': 32,
#   'Cloudiness': 92,
#   'Wind Speed': 7.16,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Wenzhou',
#   'Country': 'CN',
#   'Lat': 27.9994,
#   'Lng': 120.6668,
#   'Max Temp': 79.43,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 13.67,
#   'Current Description': 'moderate rain'},
#  {'City': 'Neepawa',
#   'Country': 'CA',
#   'Lat': 50.2289,
#   'Lng': -99.4664,
#   'Max Temp': 79.2,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 14.85,
#   'Current Description': 'clear sky'},
#  {'City': 'Nome',
#   'Country': 'US',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 51.17,
#   'Humidity': 84,
#   'Cloudiness': 94,
#   'Wind Speed': 4.21,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dingle',
#   'Country': 'PH',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 76.15,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 3.53,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Marienburg',
#   'Country': 'PL',
#   'Lat': 54.0359,
#   'Lng': 19.0266,
#   'Max Temp': 50.58,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 7.72,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tiksi',
#   'Country': 'RU',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 38.12,
#   'Humidity': 75,
#   'Cloudiness': 44,
#   'Wind Speed': 22.06,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mazatlan',
#   'Country': 'MX',
#   'Lat': 23.2167,
#   'Lng': -106.4167,
#   'Max Temp': 92.01,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Zalantun',
#   'Country': 'CN',
#   'Lat': 48,
#   'Lng': 122.7167,
#   'Max Temp': 57.83,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 4.83,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rapid City',
#   'Country': 'US',
#   'Lat': 44.0805,
#   'Lng': -103.231,
#   'Max Temp': 103.26,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 15.01,
#   'Current Description': 'clear sky'},
#  {'City': 'San Cristobal',
#   'Country': 'VE',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 82.6,
#   'Humidity': 43,
#   'Cloudiness': 86,
#   'Wind Speed': 7.96,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 64.94,
#   'Humidity': 37,
#   'Cloudiness': 2,
#   'Wind Speed': 10,
#   'Current Description': 'clear sky'},
#  {'City': 'Rio Gallegos',
#   'Country': 'AR',
#   'Lat': -51.6226,
#   'Lng': -69.2181,
#   'Max Temp': 48.72,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 16.78,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tomaszow Lubelski',
#   'Country': 'PL',
#   'Lat': 50.4477,
#   'Lng': 23.4162,
#   'Max Temp': 51.78,
#   'Humidity': 81,
#   'Cloudiness': 24,
#   'Wind Speed': 4.09,
#   'Current Description': 'few clouds'},
#  {'City': 'Haines Junction',
#   'Country': 'CA',
#   'Lat': 60.7522,
#   'Lng': -137.5108,
#   'Max Temp': 56.19,
#   'Humidity': 48,
#   'Cloudiness': 17,
#   'Wind Speed': 3.44,
#   'Current Description': 'few clouds'},
#  {'City': 'Gisborne',
#   'Country': 'NZ',
#   'Lat': -38.6533,
#   'Lng': 178.0042,
#   'Max Temp': 48.74,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 5.61,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 38.14,
#   'Humidity': 80,
#   'Cloudiness': 69,
#   'Wind Speed': 9.17,
#   'Current Description': 'broken clouds'},
#  {'City': 'Puerto Escondido',
#   'Country': 'MX',
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 80.74,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 9.55,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kokstad',
#   'Country': 'ZA',
#   'Lat': -30.5472,
# ...
#  {'City': 'Pergamino',
#   'Country': 'AR',
#   'Lat': -33.89,
#   'Lng': -60.5736,
#   'Max Temp': 71.37,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 8.14,
#   'Current Description': 'clear sky'},
#  {'City': 'Lagoa',
#   'Country': 'PT',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 71.76,
#   'Humidity': 75,
#   'Cloudiness': 3,
#   'Wind Speed': 12.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Zhigansk',
#   'Country': 'RU',
#   'Lat': 66.7697,
#   'Lng': 123.3711,
#   'Max Temp': 41.83,
#   'Humidity': 57,
#   'Cloudiness': 99,
#   'Wind Speed': 6.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sanary-Sur-Mer',
#   'Country': 'FR',
#   'Lat': 43.1178,
#   'Lng': 5.8001,
#   'Max Temp': 77.52,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Poddorye',
#   'Country': 'RU',
#   'Lat': 57.4695,
#   'Lng': 31.1156,
#   'Max Temp': 44.94,
#   'Humidity': 96,
#   'Cloudiness': 95,
#   'Wind Speed': 4.76,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pacific Grove',
#   'Country': 'US',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 94.33,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 7,
#   'Current Description': 'clear sky'},
#  {'City': 'Bac Lieu',
#   'Country': 'VN',
#   'Lat': 9.285,
#   'Lng': 105.7244,
#   'Max Temp': 79.66,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 9.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tambopata',
#   'Country': 'PE',
#   'Lat': -12.7333,
#   'Lng': -69.1833,
#   'Max Temp': 84.09,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Pimenta Bueno',
#   'Country': 'BR',
#   'Lat': -11.6725,
#   'Lng': -61.1936,
#   'Max Temp': 99.61,
#   'Humidity': 14,
#   'Cloudiness': 22,
#   'Wind Speed': 2.95,
#   'Current Description': 'few clouds'},
#  {'City': 'Tanabe',
#   'Country': 'JP',
#   'Lat': 33.7333,
#   'Lng': 135.3667,
#   'Max Temp': 75.4,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 7.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Izumo',
#   'Country': 'JP',
#   'Lat': 35.3667,
#   'Lng': 132.7667,
#   'Max Temp': 74.43,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 5.48,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Roald',
#   'Country': 'NO',
#   'Lat': 62.5833,
#   'Lng': 6.1333,
#   'Max Temp': 57.76,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Malanje',
#   'Country': 'AO',
#   'Lat': -9.5402,
#   'Lng': 16.341,
#   'Max Temp': 77.7,
#   'Humidity': 43,
#   'Cloudiness': 52,
#   'Wind Speed': 5.12,
#   'Current Description': 'broken clouds'},
#  {'City': 'Belfast',
#   'Country': 'GB',
#   'Lat': 54.5833,
#   'Lng': -5.9333,
#   'Max Temp': 61.38,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Challans',
#   'Country': 'FR',
#   'Lat': 46.8436,
#   'Lng': -1.8749,
#   'Max Temp': 68.92,
#   'Humidity': 89,
#   'Cloudiness': 61,
#   'Wind Speed': 5.3,
#   'Current Description': 'broken clouds'},
#  {'City': 'Suoyarvi',
#   'Country': 'RU',
#   'Lat': 62.0833,
#   'Lng': 32.35,
#   'Max Temp': 40.03,
#   'Humidity': 96,
#   'Cloudiness': 84,
#   'Wind Speed': 5.84,
#   'Current Description': 'broken clouds'},
#  {'City': 'Beisfjord',
#   'Country': 'NO',
#   'Lat': 68.3751,
#   'Lng': 17.5988,
#   'Max Temp': 42.85,
#   'Humidity': 80,
#   'Cloudiness': 92,
#   'Wind Speed': 1.79,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ostrovnoy',
#   'Country': 'RU',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 47.75,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 19.33,
#   'Current Description': 'light rain'},
#  {'City': 'Novo Aripuana',
#   'Country': 'BR',
#   'Lat': -5.1206,
#   'Lng': -60.3797,
#   'Max Temp': 101.86,
#   'Humidity': 14,
#   'Cloudiness': 58,
#   'Wind Speed': 4.21,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kapuskasing',
#   'Country': 'CA',
#   'Lat': 49.4169,
#   'Lng': -82.4331,
#   'Max Temp': 64.49,
#   'Humidity': 39,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Birjand',
#   'Country': 'IR',
#   'Lat': 32.8663,
#   'Lng': 59.2211,
#   'Max Temp': 68.05,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Indiana',
#   'Country': 'US',
#   'Lat': 40.0003,
#   'Lng': -86.2503,
#   'Max Temp': 82.94,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Whitehorse',
#   'Country': 'CA',
#   'Lat': 60.7161,
#   'Lng': -135.0538,
#   'Max Temp': 58.1,
#   'Humidity': 46,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Current Description': 'few clouds'},
#  {'City': 'Nangomba',
#   'Country': 'TZ',
#   'Lat': -10.9,
#   'Lng': 38.5,
#   'Max Temp': 73.11,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 6.6,
#   'Current Description': 'clear sky'},
#  {'City': 'Kindu',
#   'Country': 'CD',
#   'Lat': -2.95,
#   'Lng': 25.95,
#   'Max Temp': 72.21,
#   'Humidity': 85,
#   'Cloudiness': 33,
#   'Wind Speed': 1.32,
#   'Current Description': 'light rain'},
#  {'City': 'Sokolka',
#   'Country': 'PL',
#   'Lat': 53.4072,
#   'Lng': 23.5023,
#   'Max Temp': 49.66,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 7.43,
#   'Current Description': 'clear sky'},
#  {'City': 'Faya',
#   'Country': 'SA',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 64.92,
#   'Humidity': 42,
#   'Cloudiness': 4,
#   'Wind Speed': 1.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Macklin',
#   'Country': 'CA',
#   'Lat': 52.3334,
#   'Lng': -109.9348,
#   'Max Temp': 88.14,
#   'Humidity': 15,
#   'Cloudiness': 21,
#   'Wind Speed': 11.99,
#   'Current Description': 'few clouds'},
#  {'City': 'Nosy Varika',
#   'Country': 'MG',
#   'Lat': -20.5833,
#   'Lng': 48.5333,
#   'Max Temp': 65.3,
#   'Humidity': 90,
#   'Cloudiness': 56,
#   'Wind Speed': 2.84,
#   'Current Description': 'light rain'},
#  {'City': 'Arman',
#   'Country': 'RU',
#   'Lat': 59.7,
#   'Lng': 150.1667,
#   'Max Temp': 45.43,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 5.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nemuro',
#   'Country': 'JP',
#   'Lat': 43.3236,
#   'Lng': 145.575,
#   'Max Temp': 63.18,
#   'Humidity': 88,
#   'Cloudiness': 23,
#   'Wind Speed': 9.44,
#   'Current Description': 'few clouds'},
#  {'City': 'Simao',
#   'Country': 'CN',
#   'Lat': 22.7886,
#   'Lng': 100.9748,
#   'Max Temp': 64.4,
#   'Humidity': 99,
#   'Cloudiness': 90,
#   'Wind Speed': 2.46,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aqtobe',
#   'Country': 'KZ',
#   'Lat': 50.2797,
#   'Lng': 57.2072,
#   'Max Temp': 73.49,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Current Description': 'clear sky'},
#  {'City': 'Urucara',
#   'Country': 'BR',
#   'Lat': -2.5364,
#   'Lng': -57.76,
#   'Max Temp': 98.35,
#   'Humidity': 25,
#   'Cloudiness': 77,
#   'Wind Speed': 3.42,
#   'Current Description': 'broken clouds'},
#  {'City': 'Methoni',
#   'Country': 'GR',
#   'Lat': 36.8197,
#   'Lng': 21.7049,
#   'Max Temp': 81.21,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 10.87,
#   'Current Description': 'clear sky'},
#  {'City': 'Ljubovija',
#   'Country': 'RS',
#   'Lat': 44.1894,
#   'Lng': 19.3767,
#   'Max Temp': 62.08,
#   'Humidity': 92,
#   'Cloudiness': 73,
#   'Wind Speed': 1.59,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sampit',
#   'Country': 'ID',
#   'Lat': -2.5333,
#   'Lng': 112.95,
#   'Max Temp': 72.68,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.93,
#   'Current Description': 'light rain'},
#  {'City': 'Dondo',
#   'Country': 'MZ',
#   'Lat': -19.6094,
#   'Lng': 34.7431,
#   'Max Temp': 63.57,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 5.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Marovoay',
#   'Country': 'MG',
#   'Lat': -16.1,
#   'Lng': 46.6333,
#   'Max Temp': 71.91,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Manzhouli',
#   'Country': 'CN',
#   'Lat': 49.6,
#   'Lng': 117.4333,
#   'Max Temp': 39.24,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 12.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Batagay-Alyta',
#   'Country': 'RU',
#   'Lat': 67.8006,
#   'Lng': 130.4114,
#   'Max Temp': 32.97,
#   'Humidity': 80,
#   'Cloudiness': 29,
#   'Wind Speed': 3.47,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Paamiut',
#   'Country': 'GL',
#   'Lat': 61.994,
#   'Lng': -49.6678,
#   'Max Temp': 42.53,
#   'Humidity': 99,
#   'Cloudiness': 96,
#   'Wind Speed': 13.4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Palm Coast',
#   'Country': 'US',
#   'Lat': 29.585,
#   'Lng': -81.2078,
#   'Max Temp': 89.69,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Sapa',
#   'Country': 'PH',
#   'Lat': 5.1544,
#   'Lng': 120.3241,
#   'Max Temp': 79.77,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 4.92,
#   'Current Description': 'moderate rain'},
#  {'City': 'Ruidoso',
#   'Country': 'US',
#   'Lat': 33.3317,
#   'Lng': -105.673,
#   'Max Temp': 78.96,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Current Description': 'clear sky'},
#  {'City': 'Magoula',
#   'Country': 'GR',
#   'Lat': 38.0833,
#   'Lng': 23.5167,
#   'Max Temp': 80.65,
#   'Humidity': 55,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Current Description': 'few clouds'},
#  {'City': 'Aracati',
#   'Country': 'BR',
#   'Lat': -4.5617,
#   'Lng': -37.7697,
#   'Max Temp': 82.09,
#   'Humidity': 67,
#   'Cloudiness': 46,
#   'Wind Speed': 14.88,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lamu',
#   'Country': 'KE',
#   'Lat': -2.2717,
#   'Lng': 40.902,
#   'Max Temp': 73.62,
#   'Humidity': 82,
#   'Cloudiness': 17,
#   'Wind Speed': 16.08,
#   'Current Description': 'few clouds'},
#  {'City': 'Kerema',
#   'Country': 'PG',
#   'Lat': -7.9631,
#   'Lng': 145.7785,
#   'Max Temp': 76.57,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 4.29,
#   'Current Description': 'light rain'},
#  {'City': 'Taksimo',
#   'Country': 'RU',
#   'Lat': 56.3444,
#   'Lng': 114.8794,
#   'Max Temp': 42.73,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 1.86,
#   'Current Description': 'light rain'},
#  {'City': 'Ust-Nera',
#   'Country': 'RU',
#   'Lat': 64.5667,
#   'Lng': 143.2,
#   'Max Temp': 34.88,
#   'Humidity': 79,
#   'Cloudiness': 67,
#   'Wind Speed': 4.41,
#   'Current Description': 'broken clouds'},
#  {'City': 'Filingue',
#   'Country': 'NE',
#   'Lat': 14.3521,
#   'Lng': 3.3168,
#   'Max Temp': 93.78,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Current Description': 'clear sky'},
#  {'City': 'Pemangkat',
#   'Country': 'ID',
#   'Lat': 1.1667,
#   'Lng': 108.9667,
#   'Max Temp': 76.14,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 7.25,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Omboue',
#   'Country': 'GA',
#   'Lat': -1.5746,
#   'Lng': 9.2618,
#   'Max Temp': 74.64,
#   'Humidity': 84,
#   'Cloudiness': 5,
#   'Wind Speed': 7.83,
#   'Current Description': 'clear sky'},
#  {'City': 'Awjilah',
#   'Country': 'LY',
#   'Lat': 29.1081,
#   'Lng': 21.2869,
#   'Max Temp': 81.97,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 14.63,
#   'Current Description': 'clear sky'},
#  {'City': 'Butembo',
#   'Country': 'CD',
#   'Lat': 0.15,
#   'Lng': 29.2833,
#   'Max Temp': 56.48,
#   'Humidity': 96,
#   'Cloudiness': 45,
#   'Wind Speed': 2.21,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Himeji',
#   'Country': 'JP',
#   'Lat': 34.8167,
#   'Lng': 134.7,
#   'Max Temp': 81.28,
#   'Humidity': 85,
#   'Cloudiness': 97,
#   'Wind Speed': 6.06,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sidi Ali',
#   'Country': 'DZ',
#   'Lat': 36.0998,
#   'Lng': 0.4206,
#   'Max Temp': 73.45,
#   'Humidity': 71,
#   'Cloudiness': 13,
#   'Wind Speed': 3.85,
#   'Current Description': 'few clouds'},
#  {'City': 'Tutoia',
#   'Country': 'BR',
#   'Lat': -2.7619,
#   'Lng': -42.2744,
#   'Max Temp': 81.16,
#   'Humidity': 78,
#   'Cloudiness': 8,
#   'Wind Speed': 14.07,
#   'Current Description': 'clear sky'},
#  {'City': 'Strelka',
#   'Country': 'RU',
#   'Lat': 58.0728,
#   'Lng': 93.0344,
#   'Max Temp': 50.43,
#   'Humidity': 92,
#   'Cloudiness': 49,
#   'Wind Speed': 9.17,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sobolevo',
#   'Country': 'RU',
#   'Lat': 54.4299,
#   'Lng': 31.8996,
#   'Max Temp': 46.99,
#   'Humidity': 59,
#   'Cloudiness': 92,
#   'Wind Speed': 6.89,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sunland Park',
#   'Country': 'US',
#   'Lat': 31.7965,
#   'Lng': -106.58,
#   'Max Temp': 88.25,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Duminichi',
#   'Country': 'RU',
#   'Lat': 53.9345,
#   'Lng': 35.1099,
#   'Max Temp': 43.63,
#   'Humidity': 68,
#   'Cloudiness': 62,
#   'Wind Speed': 3.04,
#   'Current Description': 'broken clouds'},
#  {'City': 'Shimoda',
#   'Country': 'JP',
#   'Lat': 34.6667,
#   'Lng': 138.95,
#   'Max Temp': 74.1,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 7.18,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Riyadh',
#   'Country': 'SA',
#   'Lat': 24.6877,
#   'Lng': 46.7219,
#   'Max Temp': 89.74,
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 4.18,
#   'Current Description': 'clear sky'},
#  {'City': 'Berdigestyakh',
#   'Country': 'RU',
#   'Lat': 62.0989,
#   'Lng': 126.6992,
#   'Max Temp': 34.29,
#   'Humidity': 95,
#   'Cloudiness': 83,
#   'Wind Speed': 3.38,
#   'Current Description': 'broken clouds'},
#  {'City': 'Richards Bay',
#   'Country': 'ZA',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 74.57,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 15.95,
#   'Current Description': 'clear sky'},
#  {'City': 'Chara',
#   'Country': 'RU',
#   'Lat': 56.9064,
#   'Lng': 118.2631,
#   'Max Temp': 41.99,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Marinette',
#   'Country': 'US',
#   'Lat': 45.1,
#   'Lng': -87.6307,
#   'Max Temp': 68.05,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Egvekinot',
#   'Country': 'RU',
#   'Lat': 66.3167,
#   'Lng': -179.1667,
#   'Max Temp': 31.75,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 10.89,
#   'Current Description': 'snow'},
#  {'City': 'Nyurba',
#   'Country': 'RU',
#   'Lat': 63.2842,
#   'Lng': 118.3319,
#   'Max Temp': 41.74,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Shiraz',
#   'Country': 'IR',
#   'Lat': 29.6036,
#   'Lng': 52.5388,
#   'Max Temp': 80.04,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'At-Bashi',
#   'Country': 'KG',
#   'Lat': 41.1702,
#   'Lng': 75.8106,
#   'Max Temp': 55.69,
#   'Humidity': 58,
#   'Cloudiness': 11,
#   'Wind Speed': 5.66,
#   'Current Description': 'few clouds'},
#  {'City': 'Misratah',
#   'Country': 'LY',
#   'Lat': 32.3754,
#   'Lng': 15.0925,
#   'Max Temp': 83.91,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 10.11,
#   'Current Description': 'clear sky'},
#  {'City': 'Baishishan',
#   'Country': 'CN',
#   'Lat': 43.5833,
#   'Lng': 127.5667,
#   'Max Temp': 55.15,
#   'Humidity': 97,
#   'Cloudiness': 82,
#   'Wind Speed': 1.77,
#   'Current Description': 'broken clouds'},
#  {'City': 'Stykkisholmur',
#   'Country': 'IS',
#   'Lat': 65.0757,
#   'Lng': -22.7297,
#   'Max Temp': 49.57,
#   'Humidity': 78,
#   'Cloudiness': 32,
#   'Wind Speed': 0.54,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Zhangye',
#   'Country': 'CN',
#   'Lat': 38.9342,
#   'Lng': 100.4517,
#   'Max Temp': 62.38,
#   'Humidity': 29,
#   'Cloudiness': 1,
#   'Wind Speed': 7,
#   'Current Description': 'clear sky'},
#  {'City': 'Panzhihua',
#   'Country': 'CN',
#   'Lat': 26.5851,
#   'Lng': 101.7128,
#   'Max Temp': 62.17,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 1.66,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mahon',
#   'Country': 'ES',
#   'Lat': 39.8885,
#   'Lng': 4.2658,
#   'Max Temp': 81.16,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Santa Cruz Do Rio Pardo',
#   'Country': 'BR',
#   'Lat': -22.8989,
#   'Lng': -49.6325,
#   'Max Temp': 72.03,
#   'Humidity': 45,
#   'Cloudiness': 69,
#   'Wind Speed': 12.21,
#   'Current Description': 'broken clouds'}]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
